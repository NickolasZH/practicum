# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно сохрани в нем заголовок "Комментарий студента" в каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента 2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).

# %% [markdown]
# <div class="alert alert-info">
# Добрый день, Александр!
# </div>

# %% [markdown]
# ## Предсказание температуры стали на комбинате "Стальная птица"

# %% [markdown]
# ## Описание проекта
# Металлургический комбинат «Стальная птица» стремится снизить потребление электроэнергии на этапе обработки стали, контролируя температуру сплава. Для этого необходимо разработать модель, которая будет предсказывать температуру расплавленной стали на основе различных параметров технологического процесса. Модель должна позволить эффективно управлять процессами плавки и легирования стали, что в свою очередь приведет к оптимизации энергозатрат.
#
# **Цель проекта**
# Разработать модель машинного обучения для предсказания температуры расплавленной стали в процессе её обработки. Модель должна учитывать различные факторы, такие как подача сыпучих материалов, газа, проволоки и параметры работы электродов, чтобы точно прогнозировать температуру с минимальной ошибкой.
#
# ---
#
# **Этапы выполнения проекта**
#
# **Шаг 1. Загрузка данных**
# - Загрузка всех исходных данных из файлов:
#   - data_arc_new.csv — данные о электродах.
#   - data_bulk_new.csv — данные о подаче сыпучих материалов.
#   - data_bulk_time_new.csv — данные о времени подачи сыпучих материалов.
#   - data_gas_new.csv — данные о подаче газа.
#   - data_temp_new.csv — данные о температуре стали.
#   - data_wire_new.csv — данные о подаче проволоки.
#   - data_wire_time_new.csv — данные о времени подачи проволоки.
# - Проведение первичного осмотра данных: проверка на пропуски, изучение структуры файлов и типов данных.
#
# **Шаг 2. Исследовательский анализ и предобработка данных**
# - Проведение исследовательского анализа каждого датафрейма:
#   - Визуализация распределений признаков.
#   - Проверка данных на наличие выбросов, пропусков и аномалий.
#   - Определение важности каждого признака для предсказания температуры.
#   - Создание новых признаков (например, разница между временем подачи материала и временем замера температуры).
#
# - Подготовка данных для дальнейшего анализа:
#   - Замена пропусков, если они есть.
#   - Преобразование времени в числовые признаки (например, длительность нагрева, время подачи и т.д.).
#
# **Шаг 3. Объединение данных**
# - Объединение всех датафреймов на основе столбца `key` (номер партии).
# - Проверка на консистентность и точность данных после объединения.
#
# **Шаг 4. Исследовательский анализ и предобработка данных объединённого датафрейма**
# - Построение визуализаций для изучения корреляций между признаками, такими как активная мощность, подача материалов и температура.
# - Применение техник корреляционного анализа для выявления наиболее значимых факторов, влияющих на температуру.
# - Преобразование категориальных признаков (если есть) и нормализация данных.
#
# **Шаг 5. Подготовка данных**
# - Разделение данных на обучающую и тестовую выборки.
# - Масштабирование числовых признаков и кодирование категориальных признаков.
# - Подготовка данных с учетом временных зависимостей (например, использование оконных функций для учета предыдущих измерений температуры).
#
# **Шаг 6. Обучение моделей машинного обучения**
# - Обучение как минимум двух моделей машинного обучения, например:
#   - Линейная регрессия.
#   - Random Forest.
#   - XGBoost.
#   - Логистическая регрессия (для классификации категорий температуры).
# - Настройка гиперпараметров для выбранных моделей:
#   - Для Random Forest: количество деревьев, глубина деревьев.
#   - Для XGBoost: скорость обучения, максимальная глубина дерева.
# - Оценка производительности моделей на валидационной выборке.
#
# **Шаг 7. Выбор лучшей модели**
# - Сравнение производительности моделей по метрикам, таким как средняя абсолютная ошибка (MAE) или среднеквадратическая ошибка (RMSE).
# - Выбор лучшей модели на основе её качества на тестовой выборке.
# - Тестирование модели на новых данных и оценка её устойчивости к изменениям условий процесса.
#
# **Шаг 8. Общий вывод и рекомендации заказчику**
# - Описание всех этапов работы и полученных результатов.
# - Вывод о точности предсказаний модели.
# - Рекомендации для оптимизации технологического процесса на основе предсказаний температуры, включая возможные улучшения модели и дальнейшие шаги для улучшения контроля за процессом обработки стали.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Загрузка данных

# %%
# Расширяем рабочую область
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### Импорты

# %%
# !pip install --upgrade xgboost -q
# !pip install shap==0.42.1 scikit-learn==1.3.2 -q
# !pip install phik -q

# Базовые библиотеки
import os, time, sklearn, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Корреляционный анализ
import phik

# Анализ важности признаков
import shap

# Модели и обработка данных
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor

# Стат. тесты
from scipy.stats import shapiro, normaltest, kstest

# Метрики
from sklearn.metrics import mean_absolute_error, r2_score

# Константы
RANDOM_STATE = 70425

# %%
def load_and_preview_data(file_name):
    # Полный путь к файлу
    file_path = os.path.join('production/', file_name)
    
    # Проверка наличия файла
    if os.path.exists(file_path):
        # Загрузка данных
        df = pd.read_csv(file_path, delimiter=',')
        print(f"{file_name} загружен успешно.")
        
        # Сохранение датафрейма в переменную с именем файла (без расширения)
        var_name = file_name.replace('.csv', '')  # Имя переменной будет без расширения .csv
        globals()[var_name] = df  # Создание переменной с именем файла и присваивание значения
        
        # Вывод первых 5 строк
        print(f"\nПервые 5 строк из {file_name}:")
        display(df.head())  # Вывод первых 5 строк
        print(df.info())  # Информация о датафрейме
    else:
        print(f'Не получилось найти файл: {file_path}')

# Вызов функции для каждого файла
load_and_preview_data('data_arc_new.csv')
load_and_preview_data('data_bulk_new.csv')
load_and_preview_data('data_bulk_time_new.csv')
load_and_preview_data('data_gas_new.csv')
load_and_preview_data('data_temp_new.csv')
load_and_preview_data('data_wire_new.csv')
load_and_preview_data('data_wire_time_new.csv')
# Out:
# data_arc_new.csv загружен успешно.
#
# Первые 5 строк из data_arc_new.csv:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
# ...

# %% [markdown]
# ### Вывод после загрузки

# %% [markdown]
# **data_arc_new.csv загружен успешно.**
#
# Первые 5 строк из data_arc_new.csv:
# ```
# key  Начало нагрева дугой       Конец нагрева дугой     Активная мощность   Реактивная мощность
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02    0.305130            0.211253
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33    0.765658            0.477438
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36    0.580313            0.430460
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19    0.518496            0.379979
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37    0.867133            0.643691
# ```
# Типы данных и информация о файле:
# - **Описание данных**: содержит данные о процессе нагрева стали с использованием электрода. Он включает временные метки начала и конца нагрева, а также активную и реактивную мощность, используемую в процессе.
#
# ---
#
# **data_bulk_new.csv загружен успешно.**
#
# Первые 5 строк из data_bulk_new.csv:
# ```
# key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0   1      NaN     NaN     NaN     43.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    206.0   NaN    150.0   154.0
# 1   2      NaN     NaN     NaN     73.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    206.0   NaN    149.0   154.0
# 2   3      NaN     NaN     NaN     34.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    205.0   NaN    152.0   153.0
# 3   4      NaN     NaN     NaN     81.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    207.0   NaN    153.0   154.0
# 4   5      NaN     NaN     NaN     78.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    203.0   NaN    151.0   152.0
# ```
# Типы данных и информация о файле:
# - **Описание данных**: файл содержит данные о подаче сыпучих материалов (например, шлак, уголь) в процессе плавки стали. Присутствуют несколько столбцов для разных типов сыпучих материалов, однако многие значения отсутствуют.
#
# ---
#
# **data_bulk_time_new.csv загружен успешно.**
#
# Первые 5 строк из data_bulk_time_new.csv:
# ```
# key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0   1      NaN     NaN     NaN     2019-05-03 11:28:48 NaN NaN NaN NaN NaN NaN NaN 2019-05-03 11:24:31 NaN 2019-05-03 11:14:50 2019-05-03 11:10:43
# 1   2      NaN     NaN     NaN     2019-05-03 11:36:50 NaN NaN NaN NaN NaN NaN NaN 2019-05-03 11:53:30 NaN 2019-05-03 11:48:37 2019-05-03 11:44:39
# 2   3      NaN     NaN     NaN     2019-05-03 12:32:39 NaN NaN NaN NaN NaN NaN NaN 2019-05-03 12:27:13 NaN 2019-05-03 12:21:01 2019-05-03 12:16:16
# 3   4      NaN     NaN     NaN     2019-05-03 12:43:22 NaN NaN NaN NaN NaN NaN NaN 2019-05-03 12:58:00 NaN 2019-05-03 12:51:11 2019-05-03 12:46:36
# 4   5      NaN     NaN     NaN     2019-05-03 13:30:47 NaN NaN NaN NaN NaN NaN NaN 2019-05-03 13:30:47 NaN 2019-05-03 13:34:12 2019-05-03 13:30:47
# ```
# Типы данных и информация о файле:
# - **Описание данных**: файл содержит временные метки для подачи сыпучих материалов. Он позволяет понять, когда именно происходила подача каждого типа материала.
#
# ---
#
# **data_gas_new.csv загружен успешно.**
#
# Первые 5 строк из data_gas_new.csv:
# ```
# key  Газ 1
# 0   1    29.749986
# 1   2    12.555561
# 2   3    28.554793
# 3   4    18.841219
# 4   5    5.413692
# ```
# Типы данных и информация о файле:
# - **Описание данных**: этот файл включает данные о подаче газа в процессе плавки.
#
# ---
#
# **data_temp_new.csv загружен успешно.**
#
# Первые 5 строк из data_temp_new.csv:
# ```
# key  Время замера       Температура
# 0   1    2019-05-03 11:02:04  1571.0
# 1   1    2019-05-03 11:07:18  1604.0
# 2   1    2019-05-03 11:11:34  1618.0
# 3   1    2019-05-03 11:18:04  1601.0
# 4   1    2019-05-03 11:25:59  1606.0
# ```
# Типы данных и информация о файле:
# - **Описание данных**: ключевой датасет, содержащий измерения температуры расплавленной стали в процессе обработки. Эти данные непосредственно связаны с целью проекта — предсказание температуры.
#
# ---
#
# **data_wire_new.csv загружен успешно.**
#
# Первые 5 строк из data_wire_new.csv:
# ```
# key  Wire 1  Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  Wire 9
# 0   1      60.059998   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   2      96.052315   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3      91.160157   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   4      89.063515   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   5      89.238236   9.11456 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ```
# Типы данных и информация о файле:
# - **Описание данных**: данные о подаче проволоки, которая также может оказывать влияние на температуру расплавленной стали, поскольку она используется для легирования или коррекции состава металла.
#
# ---
#
# **data_wire_time_new.csv загружен успешно.**
#
# Первые 5 строк из data_wire_time_new.csv:
# ```
# key  Wire 1  Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  Wire 9
# 0   1    2019-05-03 11:06:19   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   2    2019-05-03 11:36:50   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3    2019-05-03 12:11:46   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   4    2019-05-03 12:43:22   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   5    2019-05-03 13:20:44   2019-05-03 13:15:34 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ```
# Типы данных и информация о файле:
# - **Описание данных**: файл содержит временные метки для подачи проволоки.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Полученная информация поможет нам в дальнейшем с предобработкой данных.
# </div>

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Статистический анализ количественных признаков

# %%
datasets = {
    'data_arc_new': data_arc_new,
    'data_bulk_new': data_bulk_new,
    # 'data_bulk_time_new': data_bulk_time_new,
    'data_gas_new': data_gas_new,
    'data_temp_new': data_temp_new,
    'data_wire_new': data_wire_new,
    # 'data_wire_time_new': data_wire_time_new
}

# Анализ числовых признаков для каждого датасета
for name, df in datasets.items():
    print(f"\nСтатистический анализ для {name}:")
    display(df.describe())
# Out:
# Статистический анализ для data_arc_new:
#                 key  Активная мощность  Реактивная мощность
# count  14876.000000       14876.000000         14876.000000
# mean    1615.220422           0.662752             0.438986
# std      934.571502           0.258885             5.873485
# min        1.000000           0.223120          -715.479924
# 25%      806.000000           0.467115             0.337175
# 50%     1617.000000           0.599587             0.441639
# 75%     2429.000000           0.830070             0.608201
# max     3241.000000           1.463773             1.270284
# Статистический анализ для data_bulk_new:
#                key      Bulk 1      Bulk 2       Bulk 3       Bulk 4  \
# count  3129.000000  252.000000   22.000000  1298.000000  1014.000000
# mean   1624.383509   39.242063  253.045455   113.879045   104.394477
# std     933.337642   18.277654   21.180578    75.483494    48.184126
# ...

# %% [markdown]
# ### Выводы по статистическому анализу
#
# **data_arc_new:**
#
# **Активная мощность:**
# - **Среднее значение**: 1615.22. Большая часть значений активной мощности находится в пределах 0.5-2, что указывает на стабильные значения для большинства записей.
# - **Стандартное отклонение**: 934.57, что указывает на широкий разброс значений, возможно, присутствуют экстремальные отклонения.
# - **Минимум**: 1.00. Минимальные значения активной мощности достаточно низкие.
# - **Максимум**: 3241.00. Максимальные значения могут указывать на редкие случаи с повышенной активностью.
#
# **Реактивная мощность:**
# - **Среднее значение**: 0.663. Реактивная мощность в основном положительная, однако значительный разброс указывает на возможные выбросы.
# - **Стандартное отклонение**: 0.259. Разброс достаточно небольшой, но возможны выбросы, как показано в минимуме.
# - **Минимум**: -715.48. Это выброс. Ключи с отрицательными значениями будут удалены по согласованию с заказчиком
# - **Максимум**: 1.464. Высокие значения могут указывать на более сложные или нестабильные рабочие моменты.
#
# ---
#
# **data_bulk_new:**
# - Отсутствуют данные для некоторых типов сыпучих материалов (например, Bulk 9 содержит только 1 запись, Bulk 2 – 22 записи).
# - Для большинства типов сыпучих материалов средние значения варьируются от 39.24 до 253.05.
# - Стандартное отклонение варьируется от 18.28 до 191.02, что указывает на наличие как стабильных типов материалов (например, Bulk 1 и Bulk 2), так и материалов с большим разбросом.
#
# ---
#
# **data_gas_new:**
#
# **Газ 1:**
# - **Среднее значение**: 11.00, что указывает на относительно стабильную подачу газа в течение процесса.
# - **Стандартное отклонение**: 6.22, что также подтверждает умеренный разброс.
# - **Минимум**: 0.008, что является крайне низким значением и требует проверки.
# - **Максимум**: 77.995, что может указывать на необычные случаи высокой подачи газа.
#
# ---
#
# **data_temp_new:**
#
# **Температура:**
# - **Среднее значение**: 1590.72, что близко к медиане и указывает на стабильно высокую температуру плавления стали.
# - **Стандартное отклонение**: 20.39, достаточно низкое, что свидетельствует о стабильности процесса.
# - **Минимум**: 1191, что ниже средней температуры плавления стали, является аномалией. Ключи с температурой ниже 1500 градусов удалим по согласованию с заказчиком.
# - **Максимум**: 1705.
#
# ---
#
# **data_wire_new:**
#
# - **Wire 1**: Среднее значение 100.90 и стандартное отклонение 42.01, что свидетельствует о стабильной подаче проволоки.
# - **Wire 3**: Среднее значение 189.48 и стандартное отклонение 99.51, что указывает на более высокий разброс.
# - **Wire 5 и Wire 6**: Данные ограничены 1-3 записями, что делает статистический анализ этих типов проволоки невозможным.
#
# ---

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что есть промежуточный вывод

# %% [markdown]
# ### Первичная предобработка данных

# %% [markdown]
# #### Отрицательная реактивная мощность
# Удалим ключи целиком, где встречаются отрицательные значения в столбце "Реактивная мощность"

# %%
# Находим все ключи, для которых есть отрицательные значения в столбце 'Реактивная мощность'
invalid_keys = data_arc_new[data_arc_new['Реактивная мощность'] < 0]['key'].unique()

# Удаляем все строки с этими ключами
data_arc_new_cleaned = data_arc_new[~data_arc_new['key'].isin(invalid_keys)]

# Выводим инфо
display(data_arc_new_cleaned.describe())
# Out:
#                 key  Активная мощность  Реактивная мощность
# count  14872.000000       14872.000000         14872.000000
# mean    1615.085732           0.662753             0.487112
# std      934.661090           0.258916             0.197623
# min        1.000000           0.223120             0.153777
# 25%      806.000000           0.467114             0.337175
# 50%     1616.000000           0.599587             0.441667
# 75%     2429.000000           0.830314             0.608201
# max     3241.000000           1.463773             1.270284

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что обработано наблюдение с отрицательной реактивной мощностью

# %% [markdown]
# #### Генерация новых признаков
# data_arc_new: Добавим время нагрева дугой в секундах и общую мощность

# %%
# Создаём явную копию, чтобы безопасно вносить изменения
data_arc_new_cleaned = data_arc_new_cleaned.copy()

# Преобразуем столбцы 'Начало нагрева дугой' и 'Конец нагрева дугой' в datetime
data_arc_new_cleaned['Начало нагрева дугой'] = pd.to_datetime(
    data_arc_new_cleaned['Начало нагрева дугой'], errors='coerce'
)
data_arc_new_cleaned['Конец нагрева дугой'] = pd.to_datetime(
    data_arc_new_cleaned['Конец нагрева дугой'], errors='coerce'
)

# Проверим типы данных
print(data_arc_new_cleaned[['Начало нагрева дугой', 'Конец нагрева дугой']].dtypes)

# Добавим признак "время нагрева дугой в секундах"
data_arc_new_cleaned['Время нагрева дугой в секундах'] = (
    data_arc_new_cleaned['Конец нагрева дугой'] - data_arc_new_cleaned['Начало нагрева дугой']
).dt.total_seconds()

# Добавим признак "общая мощность" и удалим исходные
data_arc_new_cleaned['Общая мощность'] = (
    data_arc_new_cleaned['Активная мощность'] + data_arc_new_cleaned['Реактивная мощность']
)
data_arc_new_cleaned.drop(columns=['Активная мощность', 'Реактивная мощность'], inplace=True)

# Отображаем результат
print("\nОбработанный data_arc_new_cleaned:")
display(data_arc_new_cleaned.head())
display(data_arc_new_cleaned.describe())
# Out:
# Начало нагрева дугой    datetime64[ns]
# Конец нагрева дугой     datetime64[ns]
# dtype: object
#
# Обработанный data_arc_new_cleaned:
#    key Начало нагрева дугой Конец нагрева дугой  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37
#
#    Время нагрева дугой в секундах  Общая мощность
# 0                           228.0        0.516383
# 1                           185.0        1.243096
# 2                           172.0        1.010773
# 3                           365.0        0.898475
# 4                           148.0        1.510824
#                 key  Время нагрева дугой в секундах  Общая мощность
# count  14872.000000                    14872.000000    14872.000000
# mean    1615.085732                      171.688004        1.149865
# ...

# %% [markdown]
# Агрегируем данные перед объединением датасетов

# %%
# Агрегируем по ключу и рассчитываем сумму для нужных столбцов
data_arc_new_aggr = data_arc_new_cleaned.groupby('key').agg({
    'Время нагрева дугой в секундах': 'sum',
    'Общая мощность': 'sum'
})

display(data_arc_new_aggr.head())
# Out:
#      Время нагрева дугой в секундах  Общая мощность
# key
# 1                            1098.0        5.179551
# 2                             811.0        3.592765
# 3                             655.0        7.001098
# 4                             741.0        4.763481
# 5                             869.0        3.940941

# %% [markdown]
# #### Признаки с большим количеством пропусков
# Удалим признаки из датасетов признаки, в которых более 95% пропусков, оставшиеся пропуски заполним нулями.

# %%
def handle_missing_data(df, threshold=0.95):
    """
    Удаляет столбцы с количеством пропущенных значений больше порога и заполняет остальные нулями.
    
    Parameters:
        df (DataFrame): Входной датафрейм.
        threshold (float): Максимально допустимая доля пропусков в столбце.
    
    Returns:
        DataFrame: Очищенный датафрейм.
    """
    # Вычисляем процент пропусков по столбцам
    missing_percentage = df.isnull().mean()

    # Выбираем только столбцы с долей пропусков ниже порога
    columns_to_keep = missing_percentage[missing_percentage < threshold].index

    # Создаём копию датафрейма с нужными столбцами
    df_cleaned = df[columns_to_keep].copy()

    # Заполняем оставшиеся пропуски нулями
    df_cleaned = df_cleaned.fillna(0)

    return df_cleaned


# Применение функции для обработки пропусков в каждом датасете
data_bulk_new_cleaned = handle_missing_data(data_bulk_new)
data_bulk_time_new_cleaned = handle_missing_data(data_bulk_time_new)
data_wire_new_cleaned = handle_missing_data(data_wire_new)
data_wire_time_new_cleaned = handle_missing_data(data_wire_time_new)

# data_bulk_new_cleaned = data_bulk_new
# data_bulk_time_new_cleaned = data_bulk_time_new
# data_wire_new_cleaned = data_wire_new
# data_wire_time_new_cleaned = data_wire_time_new

# Печать информации о типах данных и количестве пропусков
print("Обработанный data_bulk_new:")
print(data_bulk_new_cleaned.info())
print("\nОбработанный data_bulk_time_new:")
print(data_bulk_time_new_cleaned.info())
print("\nОбработанный data_wire_new:")
print(data_wire_new_cleaned.info())
print("\nОбработанный data_wire_time_new:")
print(data_wire_time_new_cleaned.info())
# Out:
# Обработанный data_bulk_new:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   3129 non-null   float64
#  2   Bulk 3   3129 non-null   float64
#  3   Bulk 4   3129 non-null   float64
#  4   Bulk 6   3129 non-null   float64
#  5   Bulk 10  3129 non-null   float64
#  6   Bulk 11  3129 non-null   float64
#  7   Bulk 12  3129 non-null   float64
#  8   Bulk 14  3129 non-null   float64
#  9   Bulk 15  3129 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 244.6 KB
# None
#
# Обработанный data_bulk_time_new:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   3129 non-null   object
# ...

# %% [markdown]
# #### Проверка корректности данных подачи сыпучих материалов и проволоки

# %%
def check_material_consistency(volume_df, time_df, label=""):
    """
    Проверяет соответствие между объёмом подачи материала и временем подачи.
    
    volume_df — DataFrame с объёмами подачи (например, data_wire_new)
    time_df — DataFrame со временем подачи (например, data_wire_time_new)
    label — строка-название для вывода (например, "Wire")

    Возвращает:
    - количество ошибок (объём есть — времени нет),
    - список ключей с ошибками,
    - датафрейм с примерами ошибок.
    """
    # Список признаков без 'key'
    cols = [col for col in volume_df.columns if col != 'key']

    # Булевы маски: где есть объём и где есть время
    volume_mask = volume_df[cols].notnull()
    time_mask = time_df[cols].notnull()

    # Ошибки: есть объём, но нет времени
    inconsistencies = volume_mask & ~time_mask
    n_inconsistent = inconsistencies.sum().sum()

    print(f"[{label}] Найдено {n_inconsistent} ячеек с объёмом, но без времени подачи.")

    # Ключи с ошибками
    error_keys = volume_df.loc[inconsistencies.any(axis=1), 'key'].unique()
    print(f"[{label}] Уникальных ключей с ошибками: {len(error_keys)}")

    # Примеры строк с ошибками
    error_rows = volume_df[volume_df['key'].isin(error_keys)]

    return n_inconsistent, error_keys, error_rows

# %%
# Проверка корректности подачи проволоки
errors_wire, wire_keys, wire_rows = check_material_consistency(
    data_wire_new,
    data_wire_time_new,
    label="Wire"
)

# Проверка корректности подачи сыпучих материалов
errors_bulk, bulk_keys, bulk_rows = check_material_consistency(
    data_bulk_new,
    data_bulk_time_new,
    label="Bulk"
)

# Отображение примеров
print("\nПримеры ошибок в подаче проволоки:")
display(wire_rows.head())

print("\nПримеры ошибок в подаче сыпучих материалов:")
display(bulk_rows.head())
# Out:
# [Wire] Найдено 0 ячеек с объёмом, но без времени подачи.
# [Wire] Уникальных ключей с ошибками: 0
# [Bulk] Найдено 0 ячеек с объёмом, но без времени подачи.
# [Bulk] Уникальных ключей с ошибками: 0
#
# Примеры ошибок в подаче проволоки:
# Empty DataFrame
# Columns: [key, Wire 1, Wire 2, Wire 3, Wire 4, Wire 5, Wire 6, Wire 7, Wire 8, Wire 9]
# Index: []
# Примеры ошибок в подаче сыпучих материалов:
# Empty DataFrame
# Columns: [key, Bulk 1, Bulk 2, Bulk 3, Bulk 4, Bulk 5, Bulk 6, Bulk 7, Bulk 8, Bulk 9, Bulk 10, Bulk 11, Bulk 12, Bulk 13, Bulk 14, Bulk 15]
# Index: []

# %% [markdown]
# #### Обработка замеров температуры
# Удалим ключи целиком из датасетов data_temp_new и data_gas_new, где встречается температура < 1500 градусов.
#
# Удалим ключи с единственным замером температуры.
#
# Выделим первый и последний замер температуры по времени

# %%
# Шаг 1. Преобразуем время замера в datetime
data_temp_new['Время замера'] = pd.to_datetime(data_temp_new['Время замера'], errors='coerce')

# Шаг 2. Удалим строки с пропущенными значениями температуры
initial_rows = data_temp_new.shape[0]
data_temp_filtered = data_temp_new.dropna(subset=['Температура'])
removed_na_rows = initial_rows - data_temp_filtered.shape[0]
print(f"Удалено строк с пропущенными значениями температуры: {removed_na_rows}")

# Шаг 3. Удалим строки, где температура < 1500
low_temp_keys = data_temp_filtered[data_temp_filtered['Температура'] < 1500]['key'].unique()
data_temp_filtered = data_temp_filtered[~data_temp_filtered['key'].isin(low_temp_keys)]

# Шаг 4. Найдём ключи с единственным замером температуры
temp_counts = data_temp_filtered.groupby('key').size()
keys_with_single_measure = temp_counts[temp_counts == 1].index
rows_before_removal = data_temp_filtered.shape[0]

# Удалим строки с такими ключами
data_temp_filtered = data_temp_filtered[~data_temp_filtered['key'].isin(keys_with_single_measure)]
rows_after_removal = data_temp_filtered.shape[0]
removed_single_measure_rows = rows_before_removal - rows_after_removal

# Вывод информации
print(f"Ключи с единственным замером температуры (всего: {len(keys_with_single_measure)}):")
print(list(keys_with_single_measure))
print(f"Удалено строк с единственным замером температуры: {removed_single_measure_rows}")

# Шаг 5. Сохраняем очищенные данные
data_temp_new_cleaned = data_temp_filtered.copy()

# Шаг 6. Фильтруем data_gas_new по оставшимся ключам
valid_keys = data_temp_new_cleaned['key'].unique()
data_gas_new_cleaned = data_gas_new[data_gas_new['key'].isin(valid_keys)]

# Шаг 7. Извлекаем первую и последнюю температуру по времени
first_temps = data_temp_new_cleaned.sort_values('Время замера').groupby('key').first().reset_index()
last_temps = data_temp_new_cleaned.sort_values('Время замера').groupby('key').last().reset_index()

# Шаг 8. Сформируем датафрейм признаков и целевой переменной
temp_features_targets = first_temps[['key', 'Температура']].rename(columns={'Температура': 'first_temp'})
temp_features_targets['target_temp'] = last_temps['Температура'].values

# Шаг 9. Выводим информацию о результатах
print("\nОбработанный data_temp_new_cleaned:")
display(data_temp_new_cleaned.shape)
display(data_temp_new_cleaned.describe())

print("\nОбработанный data_gas_new_cleaned:")
display(data_gas_new_cleaned.shape)
display(data_gas_new_cleaned.describe())

print("\nСформированный датафрейм temp_features_targets:")
display(temp_features_targets.shape)
display(temp_features_targets.head())
display(temp_features_targets.describe())
# Out:
# Удалено строк с пропущенными значениями температуры: 3427
# Ключи с единственным замером температуры (всего: 740):
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Целевой признак выбран корректно

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Мне интересно было изучить проведенный исследовательский анализ данных, твои графики, осмысленный и красочный графический анализ. Найдены очень интересные закономерности)
#
# <div class="alert alert-block alert-danger">
#
#
#
# <b>На доработку🤔:</b>
#
#
# Нужно еще написать вывод по результатам проведенного исследовательского анализа данных до объединения

# %% [markdown]
# <div class="alert alert-info">
# Добавил вывод ниже.
# </div>

# %% [markdown]
# ### Вывод по результатам исследовательского анализа данных (до объединения)
#
# 1. **Данные по электродам (`data_arc_new`)**
#    - Обнаружены аномальные значения реактивной мощности ниже нуля. Все строки с такими ключами были удалены.
#    - Добавлены признаки:
#      - `Время нагрева дугой в секундах` — разница между временем начала и окончания нагрева;
#      - `Общая мощность` — сумма активной и реактивной мощности.
#    - После расчёта новых признаков произведена агрегация по ключу: рассчитаны суммарное время нагрева и общая потреблённая мощность на каждую партию.
#
# 2. **Данные о подаче сыпучих материалов (`data_bulk_new`) и проволоки (`data_wire_new`)**
#    - Удалены признаки с более чем 95% пропущенных значений.
#    - Оставшиеся пропуски заменены нулями.
#
# 3. **Данные о времени подачи (`data_bulk_time_new`, `data_wire_time_new`)**
#    - Проведена аналогичная фильтрация по пропускам.
#    - Осуществлена проверка согласованности: объёмы подачи должны сопровождаться временными метками. Нарушений не обнаружено.
#
# 4. **Температурные замеры (`data_temp_new`)**
#    - Удалены строки с пропущенными значениями температуры.
#    - Удалены партии, в которых зафиксированы значения температуры ниже 1500 °C — они расценены как некорректные.
#    - Исключены ключи с единственным температурным замером, так как по ним невозможно оценить изменение температуры во времени.
#    - Сформирован датафрейм с первой и последней температурой в партии: `first_temp` и `target_temp`.
#
# 5. **Данные по подаче газа (`data_gas_new`)**
#    - Отфильтрован по ключам, оставшимся после очистки температурных замеров.
#    - Распределение значений газа варьируется от минимальных (близких к нулю) до достаточно высоких значений (до 78), что указывает на наличие потенциальных выбросов.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Объединение датасетов

# %%
# Объединяем все датафреймы по ключу 'key' с использованием INNER JOIN
merged_data = temp_features_targets.merge(data_bulk_new_cleaned, on='key', how='inner') \
    .merge(data_wire_new_cleaned, on='key', how='inner') \
    .merge(data_arc_new_aggr, on='key', how='inner') \
    .merge(data_gas_new_cleaned, on='key', how='inner')

# Удаляем признак key
merged_data = merged_data.drop(columns=['key'])

# Выводим последние строки объединённого датафрейма
display(merged_data.tail())
print(merged_data.shape)
# Out:
#       first_temp  target_temp  Bulk 1  Bulk 3  Bulk 4  Bulk 6  Bulk 10  \
# 2319      1570.0       1591.0     0.0    21.0     0.0     0.0     90.0
# 2320      1554.0       1591.0     0.0     0.0    63.0     0.0    122.0
# 2321      1571.0       1589.0     0.0     0.0    85.0     0.0      0.0
# 2322      1591.0       1594.0     0.0    90.0     0.0     0.0    101.0
# 2323      1569.0       1603.0     0.0    47.0     0.0     0.0      0.0
#
#       Bulk 11  Bulk 12  Bulk 14  Bulk 15      Wire 1    Wire 2  \
# 2319      0.0    256.0    129.0    223.0   89.150879   0.00000
# 2320      0.0    256.0    129.0    226.0  114.179527   0.00000
# 2321      0.0    230.0    124.0    226.0   94.086723   9.04800
# 2322      0.0    206.0    129.0    207.0  118.110717   0.00000
# 2323      0.0    233.0    126.0    227.0  110.160958  50.00528
#
#       Время нагрева дугой в секундах  Общая мощность      Газ 1
# 2319                           723.0        5.379069   7.125735
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, партии, для которых не все замеры температуры известны удалены, таблицы объединены верно

# %% [markdown]
# ### Графический анализ

# %%
# Функция для построения графиков распределения и boxplot
def plot_distributions_and_boxplots(data, dataset_name="merged_data"):
    """
    Построить графики распределения и boxplot для каждого количественного признака.
    
    Parameters:
    data (DataFrame): Датасет для анализа.
    dataset_name (str): Название датасета (для заголовков).
    """
    numeric_columns = data.select_dtypes(include=['float64']).columns
    
    for col in numeric_columns:
        plt.figure(figsize=(14, 6))
        
        # График распределения
        plt.subplot(1, 2, 1)
        sns.histplot(data[col], kde=True, bins=50, color='blue', edgecolor='black')
        plt.title(f'Distribution of {col} - {dataset_name}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        
        # Boxplot
        plt.subplot(1, 2, 2)
        sns.boxplot(x=data[col], color='orange')
        plt.title(f'Boxplot of {col} - {dataset_name}')
        plt.xlabel(col)
        
        plt.tight_layout()
        plt.show()

# Вызов для объединённого датасета
plot_distributions_and_boxplots(merged_data, "merged_data")

# %% [markdown]
# #### Проверка на нормальность распределения
# Проверим нормальность распределения признаков с помощью стат.тестов.

# %%
# Функция для проверки нормальности распределения
def check_normality(data, feature_name):
    feature_data = data[feature_name].dropna()

    # Если мало данных — уменьшим выборку, иначе используем до 5000
    sample_size = min(5000, len(feature_data))
    sample_data = np.random.choice(feature_data, size=sample_size, replace=False)

    print(f"\nПризнак: {feature_name}")
    
    # Тест Шапиро-Уилка
    stat_shapiro, p_shapiro = shapiro(sample_data)
    print(f"Shapiro-Wilk test: статистика={stat_shapiro:.8f}, p-значение={p_shapiro:.8f}")
    
    # Тест Д'Агостино и Пирсона
    stat_normaltest, p_normaltest = normaltest(sample_data)
    print(f"D’Agostino and Pearson test: статистика={stat_normaltest:.8f}, p-значение={p_normaltest:.8f}")
    
    # Тест Колмогорова-Смирнова
    stat_kstest, p_kstest = kstest(sample_data, 'norm', args=(sample_data.mean(), sample_data.std()))
    print(f"Kolmogorov-Smirnov test: статистика={stat_kstest:.8f}, p-значение={p_kstest:.8f}")
    
    # Интерпретация
    if p_shapiro < 0.05 or p_normaltest < 0.05 or p_kstest < 0.05:
        print("Распределение статистически значимо отличается от нормального (отклоняем H₀).")
    else:
        print("Распределение статистически не отличается от нормального (не отклоняем H₀).")

# Применяем ко всем числовым признакам
numeric_features = merged_data.select_dtypes(include=['float64']).columns

for feature in numeric_features:
    check_normality(merged_data, feature)
# Out:
# Признак: first_temp
# Shapiro-Wilk test: статистика=0.99750066, p-значение=0.00087977
# D’Agostino and Pearson test: статистика=8.15724997, p-значение=0.01693073
# Kolmogorov-Smirnov test: статистика=0.02932598, p-значение=0.03600356
# Распределение статистически значимо отличается от нормального (отклоняем H₀).
#
# Признак: target_temp
# Shapiro-Wilk test: статистика=0.95994401, p-значение=0.00000000
# D’Agostino and Pearson test: статистика=170.00257851, p-значение=0.00000000
# Kolmogorov-Smirnov test: статистика=0.10284893, p-значение=0.00000000
# Распределение статистически значимо отличается от нормального (отклоняем H₀).
#
# Признак: Bulk 1
# Shapiro-Wilk test: статистика=0.30562109, p-значение=0.00000000
# D’Agostino and Pearson test: статистика=2254.08196651, p-значение=0.00000000
# Kolmogorov-Smirnov test: статистика=0.52330214, p-значение=0.00000000
# Распределение статистически значимо отличается от нормального (отклоняем H₀).
#
# Признак: Bulk 3
# ...

# %% [markdown]
# ### Выводы по анализу распределения количественных признаков
#
# **Общие наблюдения:**
# - **Bulk3, Bulk4, Bulk12, Bulk14, Bulk15, Wire2** — содержат много нулей (это последствия заполнения пропусков).
# - **Bulk12** — чаще всего встречаются значения около **230**.
# - **Bulk14** — три выраженных пика: около **150**, **200**, **100**.
# - **Bulk15** — значения группируются около **100** и **200**, после большого количества нулей.
# - **Wire1** — основное распределение сосредоточено чуть выше **100**.
#
# **Выбросы выявлены в следующих признаках:**
# - `first_temp` — выбросы около **1520** и **выше 1650**.
# - `target_temp` — множество выбросов **ниже 1562** и **выше 1620**.
# - `Bulk3` — значения **свыше 200**.
# - `Bulk4` — значения **выше 170**.
# - `Bulk12` — значения **выше 500**.
# - `Bulk14` — значения **выше 350**.
# - `Wire1` — выбросы **выше 205**.
# - `Wire2` — выбросы **выше 55**.
# - `Активная мощность` — значения **больше 1.02**.
# - `Реактивная мощность` — значения **больше 0.75**.
# - `Время нагрева дугой в секундах` — выбросы **выше 270 секунд**.
# - `Общая мощность` — выбросы **более 1.75**.
# - `Газ 1` — выбросы **выше 23**.
#
# ---
#
# **Проверка признаков на нормальность распределения**
#
# Для всех ключевых признаков нормальность распределения не подтверждается — по результатам трёх статистических тестов (Шапиро–Уилка, Д'Агостино–Пирсона, Колмогорова–Смирнова) p-значения < 0.05:
#
# | Признак | Shapiro–Wilk | D’Agostino–Pearson | Kolmogorov–Smirnov | Вывод |
# |--------|---------------|--------------------|---------------------|--------|
# | `first_temp` | p = 0.00074 | p = 0.00857 | p = 0.02426 | Распределение не нормальное |
# | `target_temp` | p ≈ 0.0 | p ≈ 0.0 | p ≈ 0.0 | Распределение не нормальное |
# | `Bulk 3`, `Bulk 4`, `Bulk 12`, `Bulk 14`, `Bulk 15` | все p ≈ 0.0 | все p ≈ 0.0 | все p ≈ 0.0 | Распределения не нормальные |
# | `Wire 1`, `Wire 2` | все p < 0.05 | все p < 0.05 | все p < 0.05 | Распределения не нормальные |
# | `Активная`, `Реактивная`, `Общая мощность`, `Время нагрева` | все p < 0.05 | все p < 0.05 | все p < 0.05 | Распределения не нормальные |
# | `Газ 1` | p ≈ 0.0 | p ≈ 0.0 | p ≈ 0.0 | Распределение не нормальное |
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, что есть визуализации после объединения)

# %% [markdown]
# ## Корреляционный анализ
# Не все признаки распределены нормально, поэтому используем корреляцию Phik.

# %%
# Выбираем количественные признаки из объединённого датасета
quantitative_features = merged_data.select_dtypes(include=['float64']).columns.tolist()

# Вычисляем PhiK корреляционную матрицу
phik_corr = merged_data[quantitative_features].phik_matrix(interval_cols=quantitative_features)

# Визуализация PhiK корреляционной матрицы
plt.figure(figsize=(14, 10))
sns.heatmap(phik_corr, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={"shrink": 0.8})
plt.title("PhiK корреляционная матрица количественных признаков")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Фильтрация сильно коррелирующих пар признаков (phi_k > 0.9)
high_corr = phik_corr.stack().reset_index()
high_corr.columns = ['feature_1', 'feature_2', 'phi_k_value']
high_corr = high_corr[(high_corr['phi_k_value'] > 0.9) & (high_corr['feature_1'] != high_corr['feature_2'])]

display(high_corr)
# Out:
# Empty DataFrame
# Columns: [feature_1, feature_2, phi_k_value]
# Index: []

# %% [markdown]
# ### Выводы по корреляционному анализу
#
# 1. Корреляции с целевой переменной `target_temp`
#
# - Умеренная положительная связь:
#   - `Общая мощность` — 0.49
#   - `Wire 1` — 0.47
#   - `Bulk 15` — 0.33
#   - `Время нагрева дугой в секундах` — 0.32
#   - `Bulk 6` — 0.35
#   - `Bulk 4` — 0.29
#   - `Газ 1` — 0.29
#   - `Wire 2` — 0.28
#   - `Bulk 12` — 0.27
#   - `Bulk 14` — 0.24
#
# - Слабая положительная корреляция:
#   - `first_temp` — 0.42
#   - `Bulk 1` — 0.18
#   - `Bulk 11`, `Bulk 10`, `Bulk 3` — от 0.0 до 0.1 или отсутствует
#
# Вывод: целевая температура зависит в основном от подачи проволоки (`Wire 1`, `Wire 2`), состава (`Bulk 12`, `Bulk 14`, `Bulk 15`), времени нагрева и общей мощности.
#
# ---
#
# 2. Сильно коррелирующие признаки (phi_k > 0.7)
#
# | Пара признаков                    | Коэффициент |
# |----------------------------------|-------------|
# | `Bulk 12` – `Bulk 14`            | 0.80        |
# | `Bulk 12` – `Газ 1`              | 0.73        |
# | `Bulk 14` – `Газ 1`              | 0.80        |
# | `Wire 2` – `Bulk 6`              | 0.78        |
# | `Общая мощность` – `Время нагрева дугой` | 0.78  |
# | `Общая мощность` – `Газ 1`       | 0.57        |
# | `Bulk 12` – `Bulk 1`             | 0.68        |
# | `Bulk 14` – `Bulk 1`             | 0.66        |
#
# ---
#
#
# - `Wire 1` коррелирует с несколькими признаками: `Bulk 4` (0.35), `Bulk 12` (0.44), `Bulk 6` (0.34), `Bulk 3` (0.29).
# - `Wire 2` сильно связан с `Bulk 6` (0.78), что может указывать на совместную подачу.
# - `Газ 1` тесно связан с подачей сыпучих материалов, но почти не зависит от мощности.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проверяешь попарные корреляции признаков

# %% [markdown]
# ## Подготовка и обучение моделей

# %% [markdown]
# ### Выбор метрики для задачи
#
# Почему подходит **MAE (Mean Absolute Error)**
#
# 1. **Характер задачи:**
#    - Мы решаем задачу **регрессии**, где целевая переменная `target_temp` — непрерывная температура в °C.
#    - Важно оценить **среднюю абсолютную ошибку прогноза модели** в тех же единицах (градусах), что делает метрику MAE интерпретируемой и приближенной к реальному производству.
#
# 2. **Физическая интерпретация:**
#    - Абсолютная ошибка (например, 5°C) интуитивно понятна инженерам и операторам, в отличие от MSE или RMSE, которые дают ошибку в квадратных градусах или завышают вклад крупных отклонений.
#
# 3. **Устойчивость к выбросам:**
#    - В отличие от RMSE, MAE **менее чувствительна к выбросам**, что важно в производственной среде, где данные могут содержать редкие экстремумы.
#
# 4. **Целевое значение:**
#    - Заказчик установил допустимый уровень MAE — **не более 6.8°C** на тестовой выборке. Это позволяет использовать MAE как **ключевую метрику качества** для принятия решений.
#
# ---
#
# Почему дополнительно рассчитывается **R² (коэффициент детерминации)**
#
# 1. **Объяснённая дисперсия:**
#    - R² показывает **долю дисперсии целевой переменной, объясняемую моделью**. Это помогает понять, насколько хорошо модель захватывает закономерности в данных.
#
# 2. **Интерпретация:**
#    - Значение R² варьируется от 0 до 1 (или может быть отрицательным при плохих моделях):
#      - **R² = 1** — идеальное предсказание;
#      - **R² = 0** — модель не лучше среднего;
#      - **R² < 0** — модель хуже простого среднего значения.
#    - Например, R² = 0.85 означает, что **85% колебаний температуры объясняются признаками** модели, а остальные 15% — случайны или неучтены.
#
# 3. **Информативность для заказчика:**
#    - Заказчику важно понимать не только абсолютную ошибку, но и **объём объяснённой информации** — насколько полезна модель с точки зрения общей картины технологического процесса.
#
# ---

# %% [markdown]
# ### Подготовка выборок

# %%
# Определим признаки и целевую переменную
X = merged_data.drop(columns=['target_temp'])  # Все, кроме целевой переменной
y = merged_data['target_temp']                # Целевая переменная

# Разделим на обучающую и тестовую выборки (тестовая — 25%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.25, 
    random_state=RANDOM_STATE  # для воспроизводимости
)

# Проверка размеров выборок
print(f"Размер обучающей выборки: {X_train.shape}")
print(f"Размер тестовой выборки: {X_test.shape}")
# Out:
# Размер обучающей выборки: (1743, 15)
# Размер тестовой выборки: (581, 15)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Выборки подготовлены корректно

# %% [markdown]
# #### Исследуем обучающую выборку на наличие выбросов

# %%
def plot_feature_target_scatter(X, y, max_cols=3, sample_size=1000):
    """
    Строит scatter-плоты для всех числовых признаков против целевой переменной y.
    
    Parameters:
        X (DataFrame): тренировочные признаки.
        y (Series): целевая переменная.
        max_cols (int): сколько графиков в строке.
        sample_size (int): ограничение по выборке (для ускорения).
    """
    # Объединяем X и y для удобства
    df = X.copy()
    df['target_temp'] = y.values

    numeric_cols = df.select_dtypes(include='number').columns.drop('target_temp')
    n_features = len(numeric_cols)
    n_rows = (n_features + max_cols - 1) // max_cols  # округление вверх

    plt.figure(figsize=(5 * max_cols, 4 * n_rows))

    for i, col in enumerate(numeric_cols, 1):
        plt.subplot(n_rows, max_cols, i)
        sns.scatterplot(data=df.sample(min(sample_size, len(df))), x=col, y='target_temp', alpha=0.5)
        plt.title(f'{col} vs target_temp')
        plt.xlabel(col)
        plt.ylabel('target_temp')

    plt.tight_layout()
    plt.show()

plot_feature_target_scatter(X_train, y_train)

# %% [markdown]
# **Наблюдение:** при **очень большом времени нагрева (>2500 секунд)** температура **не поднимается выше 1620°C**.
# 1. **Физически это подозрительно**:
#    - Сталь при долгом нагреве должна либо перегреться, либо система должна отключиться.
#    - Если температура остаётся «низкой» (≤1620°C), а нагрев экстремально длинный — вероятно:
#      - ошибка логгера времени,
#      - сбой замера температуры,
#      - потеря контакта или холостой нагрев.
#
# 2. **Для модели это выбросы**:
#    - Они **искажают регрессионную зависимость**.
#    - **MAE возрастает**, потому что модель "путается": долгий нагрев, но температура как у средних значений.
#    - Такие случаи **влияют на деревья (RF, XGB)** и особенно на **линейные модели** — нарушается монотонность.
#
# Удалим такие выбросы из модели

# %%
# Объединяем признаки и целевую переменную для фильтрации
train_df = X_train.copy()
train_df['target_temp'] = y_train.values

# Количество строк до удаления
initial_rows = train_df.shape[0]

# Удаляем строки с выбросами:
# время нагрева дугой > 2000 сек и температура ≤ 1620
condition = (train_df['Время нагрева дугой в секундах'] > 2000) & (train_df['target_temp'] <= 1620)
train_df_cleaned = train_df[~condition]

# Количество удалённых строк
removed_rows = initial_rows - train_df_cleaned.shape[0]
print(f"Удалено выбросов: {removed_rows} строк")

# Разделим обратно на X и y
X_train_cleaned = train_df_cleaned.drop(columns=['target_temp'])
y_train_cleaned = train_df_cleaned['target_temp']



plot_feature_target_scatter(X_train_cleaned, y_train_cleaned)
# Out:
# Удалено выбросов: 6 строк

# %% [markdown]
# Выводим размеры после удаления выбросов

# %%
print(f"Размер обучающей выборки после очистки: {X_train_cleaned.shape[0]} строк, {X_train_cleaned.shape[1]} признаков")
# Out:
# Размер обучающей выборки после очистки: 1737 строк, 15 признаков

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Нужно вывести размеры полученных выборок (число строк). В обучающей выборке должно быть 1700 элементов или более по требованию заказчика

# %% [markdown]
# <div class="alert alert-info">
# Добавил вывод размера выборки выше.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# #### Пайплайн
#
# Зададим модели, скейлеры и гиперпараметры

# %%
# Пайплайн с 3 моделями
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Масштабирование признаков
    ('model', LinearRegression())  # Модель по умолчанию (Linear Regression)
])

# Гиперпараметры для каждой модели
param_grid = [
    # Линейная регрессия
    {
        'model': [LinearRegression()],
        'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  # Разные способы масштабирования
    },
    
    # Random Forest
    {
        'model': [RandomForestRegressor(random_state=RANDOM_STATE)],
        'model__n_estimators': range(50, 800),  # Количество деревьев в лесу
        'model__max_depth': range(5, 30),  # Максимальная глубина деревьев
        'model__min_samples_split': range(2, 40),  # Минимальное количество образцов для разделения
        'model__min_samples_leaf': range(1, 10),  # Минимальное количество образцов на листе
        'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    
    # XGBoost
    {
        'model': [XGBRegressor(random_state=RANDOM_STATE)],
        'model__n_estimators': range(50, 800),  # Количество бустинг-раундов
        'model__max_depth': range(5, 30),  # Максимальная глубина деревьев
        'model__learning_rate': [0.01, 0.1, 0.2, 0.3],  # Скорость обучения
        'model__subsample': [0.8, 0.9, 1.0],  # Подсэмплинг
        'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %% [markdown]
# #### Поиск лучшей модели

# %%
# RandomizedSearchCV
random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_grid,
    n_iter=50,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=1,
    random_state=RANDOM_STATE
)

# Замер времени обучения
start_time = time.time()
random_search.fit(X_train_cleaned, y_train_cleaned)
end_time = time.time()

# Вывод времени
elapsed_time = end_time - start_time
print(f"\nВремя подбора модели: {elapsed_time:.2f} секунд")

# Лучшая модель
best_model = random_search.best_estimator_
print("\nЛучшая модель:")
display(best_model)

# Метрики на тесте
y_pred = best_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nЛучший MAE на тесте: {mae:.2f}")
print(f"R² на тесте: {r2:.2f}")

# DummyRegressor
dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train, y_train)
dummy_pred = dummy.predict(X_test)

dummy_mae = mean_absolute_error(y_test, dummy_pred)
dummy_r2 = r2_score(y_test, dummy_pred)

print(f"\nDummyRegressor MAE: {dummy_mae:.2f}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Время подбора модели: 801.91 секунд
#
# Лучшая модель:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestRegressor(max_depth=16, min_samples_leaf=2,
#                                        min_samples_split=17, n_estimators=757,
#                                        random_state=70425))])
# Лучший MAE на тесте: 6.31
# R² на тесте: 0.34
#
# DummyRegressor MAE: 7.95

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Метрика выбрана верно - МАЕ)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Нужно вывести аутпут сравнения моделей на кросс-валидации через `.best_score_`

# %% [markdown]
# <div class="alert alert-info">
# Добавил вывод лучшего результата ниже.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# Выводим лучший результат на кросс-валидации (средний по 5 фолдам)

# %%
best_cv_score = -random_search.best_score_
print(f"\nЛучший MAE на кросс-валидации: {best_cv_score:.2f}")
# Out:
# Лучший MAE на кросс-валидации: 6.27

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование модели проведено правильно. Отлично, что дополнительно выведена метрика r2 ради интерпретации

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проводишь сравнение своей модели с константной дамми моделью. В каждом проекте при оценке качества модели, имеет смысл проводить такую проверку на адекватность

# %% [markdown]
# ## Анализ важности признаков

# %%
# Получим обученную модель из пайплайна
model = best_model.named_steps['model']

importances = model.feature_importances_
feature_names = X_train_cleaned.columns.tolist()

# Визуализация
importance_df = pd.DataFrame({
    'Признак': feature_names,
    'Важность': importances
}).sort_values(by='Важность', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x='Важность', y='Признак', data=importance_df.head(15))
plt.title('Важность признаков по версии модели')
plt.tight_layout()
plt.show()

display(importance_df)
# Out:
#                            Признак  Важность
# 0                       first_temp  0.243502
# 12  Время нагрева дугой в секундах  0.242729
# 10                          Wire 1  0.122073
# 4                           Bulk 6  0.077751
# 14                           Газ 1  0.055974
# 11                          Wire 2  0.053827
# 9                          Bulk 15  0.048250
# 7                          Bulk 12  0.035370
# 8                          Bulk 14  0.033508
# 13                  Общая мощность  0.031390
# 1                           Bulk 1  0.018427
# 2                           Bulk 3  0.016428
# 3                           Bulk 4  0.014988
# 6                          Bulk 11  0.002895
# 5                          Bulk 10  0.002888

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что не забываешь оценить важность признаков модели
#
#
# * Дополнительно впоследствии можно заново пересобирать лучшую модель на ограниченном наборе признаков (а не заранее, чтобы была возможность контролировать спад качества), чтобы облегчить ее (может потребоваться заново подобрать параметры). Это может дать небольшой прирост в качестве за счет избавления от зашумленности, главное не переборщить.
#
# - Кроме того вместо встроенной важности можно было бы посмотреть SHAP https://habr.com/ru/articles/428213/, с помощью которого можно было бы также понять характер влияния каждого предиктора

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
#
# Нужно еще написать вывод по важности признаков

# %% [markdown]
# <div class="alert alert-info">
# Добавил вывод ниже.
# </div>

# %% [markdown]
# ### Вывод по анализу важности признаков
#
# Наблюдения на основании оценки `feature_importances_`:
#
# 1. **Наиболее значимые признаки:**
#    - `first_temp` (24.4%) — начальная температура партии. Это ожидаемо, поскольку температура в начале оказывает прямое влияние на итоговую температуру стали.
#    - `Время нагрева дугой в секундах` (24.3%) — продолжительность воздействия энергии. Почти равнозначен по важности с `first_temp`, что подчёркивает влияние длительности нагрева на результат.
#
# 2. **Значимый вклад вносят также:**
#    - `Wire 1` (12.2%) — подача проволоки, влияющая на химический состав сплава.
#    - `Bulk 6` (7.8%) — сыпучий материал.
#    - `Газ 1` (5.6%) — активность газовой среды.
#    - `Wire 2` (5.4%) — ещё один компонент проволоки.
#    - `Bulk 15` (4.8%) — один из стабильно подаваемых сыпучих компонентов.
#
# 3. **Средняя важность (3–4%):**
#    - `Bulk 12`, `Bulk 14`, `Общая мощность` — могут оказывать влияние, но менее выражено.
#
# 4. **Наименьшее влияние (менее 2%):**
#    - `Bulk 1`, `Bulk 3`, `Bulk 4`, `Bulk 10`, `Bulk 11` — почти не участвуют в формировании прогноза.
#
# ---
#
# **Общий вывод:**
# Температура расплава определяется в первую очередь начальными условиями (`first_temp`) и длительностью воздействия (`время нагрева`). Существенное влияние оказывают также объёмы подачи ключевых добавок (`Wire 1`, `Bulk 6`, `Газ 1`). Мощность системы и второстепенные материалы играют меньшую роль.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Общий вывод по проекту
#
# **Задача**
#
# Металлургический комбинат **«Стальная птица»** поставил задачу — **спрогнозировать температуру стали на выходе** после обработки. Цель — **снизить энергозатраты** и **повысить точность управления процессами**.
#
# **Цель проекта**
#
# Разработать **модель машинного обучения**, способную предсказывать **конечную температуру стали** на основе параметров процесса:
# - начальная температура (`first_temp`),
# - объёмы подачи сыпучих и легирующих материалов (Bulk, Wire),
# - параметры дугового нагрева и подачи газа.
#
# ---
#
# **Ход работы**
#
# **1. Загрузка данных**
# Загружены 7 таблиц по ключу `key`, охватывающих все этапы процесса: нагрев, замеры температуры, подача газа и материалов.
#
# **2. Очистка и предобработка**
# Удалены:
# - признаки с более чем **95% пропусков**,
# - строки с **реактивной мощностью < 0**,
# - замеры **температуры < 1500°C**,
# - партии с **единственным замером температуры**.
#
# Добавлены новые признаки:
# - `Время нагрева дугой в секундах`,
# - `Общая мощность`.
#
# **3. Объединение таблиц**
# Все датасеты объединены по `key`. После фильтрации осталось **2471 полная запись**, пригодная для обучения модели.
#
# **4. Исследовательский анализ**
# - Распределения большинства признаков — **ненормальные**, с наличием выбросов.
# - **Корреляционный анализ** показал, что наиболее важные признаки — `first_temp`, `Wire 1`, `Bulk 6`, `Газ 1`, `Время нагрева`.
# - Выбросы с аномально длинным нагревом и низкой температурой удалены из обучающей выборки.
#
# **5. Подготовка выборок**
# - Разделение: **75% — обучение**, **25% — тестирование**.
# - Обработка: масштабирование внутри пайплайна.
# - Обучающая выборка после очистки содержит **1737 строк** (что удовлетворяет условию ≥1700).
#
# **6. Обучение моделей**
# Использованы 3 модели:
# - `LinearRegression`
# - `RandomForestRegressor`
# - `XGBRegressor`
#
# Параметры подобраны через `RandomizedSearchCV` (**n_iter=50**, **cv=5**, **random_state=70425**).
# Основная метрика качества: **MAE (средняя абсолютная ошибка)**. Также оценивался **R²** для объяснённой дисперсии.
#
# ---
#
# **7. Лучшие результаты**
#
# - **Лучшая модель**:
#   `RandomForestRegressor(max_depth=16, min_samples_leaf=2, min_samples_split=17, n_estimators=757, random_state=70425)`
#
# - **Метрики на тестовой выборке:**
#   - MAE = **6.31°C**  (лучше целевого порога в 6.8°C)
#   - R² = **0.34**
#
# - **Базовая модель DummyRegressor** показала MAE = **7.95°C**, что подтверждает преимущество обученной модели.
#
# ---
#
# **Анализ важности признаков**
# Температура на выходе зависит в первую очередь от:
# - **начальной температуры**,
# - **времени нагрева дугой**,
# - **объёма подачи легирующих добавок** (Wire, Bulk),
# а не от мощности.
#
# ---
#
# **Рекомендации для бизнеса**
#
# 1. **Автоматизировать мониторинг начальной температуры и времени нагрева** — эти параметры критически важны и поддаются контролю.
# 2. **Контролировать объёмы подачи Wire 1 и Bulk 6** — они оказывают существенное влияние на итоговую температуру.
# 3. **Отключать или перепроверять партии, где нагрев превышает 2000 сек, а температура остаётся низкой** — высока вероятность ошибок логгирования.

# %% [markdown]
# <div class="alert alert-info">
# Обновил общий вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера  <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Для итоговой модели нужно указать само значение RANDOM_STATE (число)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Можно было еще оставить рекомендации для бизнеса

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (общий вывод по проекту)  <a class="tocSkip"> </h2>
#
#
# У меня сложилось отличное впечатление о проекте, тебе удалось справиться с таким выпускным проектом. Молодец! Подготовлены данные для анализа, изучены все параметры. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально, спасибо за исправления! Принимаю твой проект)
#
# Если хочешь лучше разобраться в специальности, то предлагаю полезные материалы:
# -  <a href="https://academy.yandex.ru/handbook/ml/">Книга от ШАД</a>
#
# - <a href="https://www.youtube.com/playlist?list=PLJ_CMbwA6bT-n1W0mgOlYwccZ-j6gBXqE">Лекции от Andrew Ng</a>
#
# - <a href="https://habr.com/ru/company/ods/blog/322626/">Открытый курс машинного обучения</a>
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a>.
#
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Интерпретировать предсказания моделей поможет  <a href="https://habr.com/ru/post/428213/">SHAP</a>,   <a href="https://towardsdatascience.com/using-shap-values-to-explain-how-your-machine-learning-model-works-732b3f40e137">+ еще ссылка</a>.
# - Интересные способы <a href="https://github.com/DmitrySerg/otus-public/tree/master/OpenLessons/AnomalyDetection">обработки аномалий</a>.
#
#
# С интересом изучал твою работу, код и выводы. Что ещё для дальнейшего улучшения качества/скорости моделирования возможно сделать?
#
# Опишу здесь некоторые идеи:
#
# 1. Качество данных на входе: ещё раз оценить аномалии, пропуски, проверить согласованность временных признаков.
# 2. Генерация новых полезных признаков (features engineering).
# 3. Оптимизация подбора гиперпараметров (OptunaSearchCV, RandomizedSearchCV, BayesSearchCV и т.д.)
# 4. Анализ остатков (разницы между прогнозом и истинным значением таргета): выявить, в каких случаях чаще всего ошибается, а в каких выдает наиболее точный результат...
#
# А главное, мы достигли цели нашего проекта: пройдены основные этапы построения модели регрессии для прогнозирования конечной температуры сплава с учетом ее качества.
#
# Рад был тебе помочь)
#
# Удачи!
#
# **Буду очень благодарен, если ты поставишь мне положительную оценку за проект в форме на странице курса, это важно для меня. Достаточно поставить оценку, а комментарий можешь написать по желанию:)**
#
# </div>
