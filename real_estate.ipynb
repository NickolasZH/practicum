# %% [markdown]
# <div class="alert alert-success">
#   <b> ✔️Комментарий ревьюера ✔️</b>
#
# Привет, Николай! Меня зовут Михаил, я буду проверять твой проект. Предлагаю общаться на 'ты' :)
# Однако, если это неудобно - сообщи, и мы перейдем на 'Вы'. Моя главная цель —  поделиться с тобой своим опытом и помочь тебе стать крутым специалистом, а не только указать на совершенные тобой ошибки.
#
# Видно, что к проекту приложен большой труд. Все ключевые этапы в работе выполнены, статистическое исследование проведено качественно. Так что в целом справиться с задачей тебе удалось.
#
# Есть несколько аспектов, которые **требуют** твоего **внимания**. Комментарии по ним помечены красным цветом и символами ❌. После их доработки проект будет принят, осталось совсем немного :)
#
#
# Давай работать над проектом в диалоге: если **ты что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Мне будет легче отследить изменения, если ты будешь использовать синюю форму, которую я прикреплю ниже. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
#
# Жду проект на повторное ревью. Успехов в изучении!
#
#
#
# </div>
# <div class="alert alert-block alert-danger"> <b>❌ Комментарий ревьюера ❌</b>
#     Так я выделяю моменты, которые требуют особого внимания. Нужно будет учесть их и внести корректировки в свою работу. </div>
# <div class="alert alert-block alert-warning"> <b>⚠️ Комментарий ревьюера ⚠️</b>
#     Желтым я отмечу рекомендации, которые, могут быть полезными при твоей работе. Они носят рекомендационный характер, но будет классно, если ты будешь учитывать их при работе.</div>
# <div class="alert alert-block alert-success"> <b>✔️ Комментарий ревьюера ✔️</b>
#     Так я выделяю удачные и элегантные решения, на которые можно опираться в будущих проектах.</div>
# <div class="alert alert-block alert-info">
#
# А в таком блоке ты можешь оставить комментарии для меня
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    Рекомендую добавить к работе небольшой план работы, написанный своими словами - навык составления ТЗ пригодится в будущем
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Приветствую!
# Чек-лист выполнения задания:
#
#     - Оценена общая картина и готовность датасета к анализу
#     - Исследованы столбцы датасета: их распределение и наполненность
#     -  Пропуски обработаны, заполнены где возможно
#     -  Типы данных изменены, где необходимо
#     -  Новые столбцы по заданию добавлены
#     -  Исследования по столбцам, указанным в задании проведены
#     -  Детально исследована скорость продажи квартир по заданию
#     -  Определены, по заданию, факторы, влияющие на стоимость
#     -  Проанализированы 10 населённых пунктов с наибольшей частотой размещения
#     -  Рассчитана средняя стоимость квартир в Санкт-Петербурге
#     -  Подготовлен общий вывод
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Отлично👍
#
# </div>
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
# Импортируем библиотеки и прочитаем файл
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('real_estate/real_estate_data.csv', sep='\t')

# %%
# Выведем первые 20 строк датасета на экран
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
# Выведем общую информацию о датасете
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **Дополнительно для удобства перенесём расшифровку полей датасета из задания:**
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %%
# Построим гистограмму для всех числовых значений графика
data.hist(figsize=(15, 20))
# Out:
# array([[<Axes: title={'center': 'total_images'}>,
#         <Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'rooms'}>],
#        [<Axes: title={'center': 'ceiling_height'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'living_area'}>,
#         <Axes: title={'center': 'floor'}>],
#        [<Axes: title={'center': 'kitchen_area'}>,
#         <Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'airports_nearest'}>,
#         <Axes: title={'center': 'cityCenters_nearest'}>],
#        [<Axes: title={'center': 'parks_around3000'}>,
#         <Axes: title={'center': 'parks_nearest'}>,
#         <Axes: title={'center': 'ponds_around3000'}>,
#         <Axes: title={'center': 'ponds_nearest'}>],
#        [<Axes: title={'center': 'days_exposition'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Хорошо. Гистограммы построены.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Какие выводы по ним мы можем сделать?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Если быть честным, я не до конца понимаю, какие выводы я могу сделать по этим данным.
# 1. Данные есть. 17 столбцов разных типов.
# 2. Данных, кажется, достаточно для анализа по каждой категории.
# 3. Данные по-разному распределены.
#
# Всё.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошо👍 Продолжаем проверку
#
# </div>
#
# </div>

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# #### Обработка пропусков

# %%
# Выведем количество пропущенных значений для каждого столбца
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Итого по пропускам:
#
#     - ceiling_height (высота потолков): 9195;
#     - floors_total (этажей в доме): 86;
#     - living_area (жилая площадь, квм): 1903;
#     - is_apartment (апартаменты): 20924;
#     - kitchen_area (площадь кухни, квм): 2278;
#     - balcony (число балконов): 11519;
#     - locality_name (название населённого пункта): 49;
#     - airports_nearest (расстояние до ближайшего аэропорта, м): 5542;
#     - cityCenters_nearest (расстояние до центра города, м): 5519;
#     - parks_around3000 (число парков в радиусе 3 км): 5518;
#     - parks_nearest (расстояние до ближайшего парка, м): 15620;
#     - ponds_around3000 (число водоёмов в радиусе 3 км): 5518;
#     - ponds_nearest (расстояние до ближайшего водоёма, м): 14589;
#     - days_exposition (сколько дней было размещено объявление): 3181.

# %% [markdown]
# ##### Высота потолков (ceiling_height)

# %%
# Для графика нам не нужны пропуски
ceiling_heights = data['ceiling_height'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(ceiling_heights, bins=30, range=(1.5, 4), edgecolor='black') # Сразу ограничим распределение от 1.5 до 4 метров
plt.title('Распределение по высоте потолков')
plt.xlabel('Высота потолков, м')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Распределение высоты потолков на графике выглядит асимметричным, с заметным преобладанием высоты в диапазоне от 2.5 до 3 метров. Медиана будет наименее подвержена влиянию выбросов и экстремальных значений, поэтому она является хорошим выбором для замены пропусков.

# %%
# Посчитаем медианную высоту потолков
median_ceiling_height = ceiling_heights.median()
median_ceiling_height
# Out:
# np.float64(2.65)

# %%
# Заменим пропуски медианным значением
data['ceiling_height'].fillna(median_ceiling_height, inplace=True)

# И проверим, заполнились ли пропуски
data.isna().sum()
# Out:
# /tmp/ipykernel_6533/1455441853.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ceiling_height'].fillna(median_ceiling_height, inplace=True)
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# ...

# %% [markdown]
# Пропуски при заполнении высоты потолков могут возникать по нескольким основным причинам:
# 1. **Отсутствие стандартной практики измерения**:
# - Высота потолков не всегда является обязательным параметром для указания при продаже недвижимости. В отличие от таких характеристик, как площадь или количество комнат, высота потолков редко фиксируется в обязательном порядке.
#
# 2. **Неважность для покупателя/продавца**:
# - Для многих категорий недвижимости высота потолков может не считаться критически важным параметром. Например, для покупателей квартир в стандартных многоквартирных домах это может быть второстепенной характеристикой, и продавцы могут не считать нужным указывать её.
#
# 3. **Разные источники данных**:
# - Если данные о недвижимости поступают из различных источников (например, государственных реестров, агентств или частных объявлений), один из них может просто не содержать информации о высоте потолков. Это приводит к пропускам, когда данные объединяются в общую базу.
#
# 4. **Разнообразие зданий**:
# - В старых или нестандартных зданиях высота потолков может варьироваться в разных частях дома или квартиры, что затрудняет её единообразное указание. Это может привести к тому, что высота потолков не указывается вовсе, чтобы избежать путаницы.
#
# 5. **Реконструкция или ремонт**:
# - В некоторых случаях здание или квартира могли пройти реконструкцию или ремонт, в ходе которого высота потолков изменилась (например, установка подвесных потолков). При отсутствии точных данных после реконструкции это поле может остаться незаполненным.
#
# 6. **Ошибка или лень при вводе данных**:
# - Человеческий фактор также играет важную роль. При заполнении анкет или объявлений владельцы или агенты могут просто забыть указать высоту потолков, особенно если это поле не является обязательным.
#
# 7. **Трудность измерения**:
# - Измерить точную высоту потолков может быть затруднительно, особенно в старых зданиях или объектах с высокими потолками, где точное измерение может требовать дополнительных усилий или оборудования.

# %% [markdown]
# ##### Этажей в доме (floors_total)

# %%
# Построим гистограмму частотности по этажам
floors_total = data['floors_total'].dropna()

plt.figure(figsize=(8, 6)) 
plt.hist(floors_total, bins=30, edgecolor='black')
plt.title('Распределение по количеству этажей в доме')
plt.xlabel('Количество этажей')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Пропусков в столбце floors_total действительно мало, можно сразу удалить их
#
# </div>

# %%
# Выведем медианное значение кол-ва этажей по всем данным
data['floors_total'].median()
# Out:
# np.float64(9.0)

# %% [markdown]
# На графике видно, что чаще всего встречаются дома с 5, 9, 16 и 25 этажами. С первого взгляда, не смотря на то, что медианное количество этажей равно 9, не понятно, каким значением стоит заполнить пропуски. Предположим, что этажность застройки отличается от размера населённого пункта.
#
# **Сгруппируем населённые пункты по размеру, учитывая названия:**
# - Санкт-Петербург, если название города Санкт-Петербург;
# - Окрестности - остальные населённые пункты.

# %%
# Заменяем все пропуски в названии населённых пунктов на "Неизвестный"
# data['locality_name'].fillna('Неизвестный', inplace=True)

## Исправление: удаляем пропуски в locality_name, т.к их достаточно мало
data['locality_name'].dropna(inplace=True)

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Пропусков в столбце locality_name мало, лучше сразу удалить их, это не снизит качество данных - а вот заполнение значением, которое не является названием населенного пункта, может исказить дальнейший анализ
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Пропуски удалил, благодарю за корректировку.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Исправлено👍
#
# </div>
#
# </div>

# %%
# Выведем количество населённых пунктов
localities_number = data['locality_name'].nunique()
localities_number
# Out:
# 364

# %%
# Выведем названия населённых пунктов
localities = data['locality_name'].unique()
localities
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Заметно довольно много дубликатов. Чтобы было проще группировать населённые пункты, избавимся от неявных дубликатов: поменяем все "ё" на "е", затем напишем функцию, которая будет унифицировать названия населённых пунктов, основываясь на последнем слове в названии.

# %%
# Меняем "ё" на "е"
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
localities_number = data['locality_name'].nunique()
localities_number
# Out:
# 330

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#
#    Хорошая работа. Также рекомендую хорошую статью по предобработке, в ней есть интересные способы обработки неявных дубликатов: https://proglib.io/p/moem-dataset-rukovodstvo-po-ochistke-dannyh-v-python-2020-03-27 В пункте 8 есть интересная информация о работе с опечатками в названиях населенных пунктов
#
# </div>

# %%
# Создаем функцию для переименования дубликатов по последнему слову
def rename_duplicates_by_last_word(dataframe, column_name):
    # Извлекаем последнее слово из названий населенных пунктов
    last_word_series = dataframe[column_name].apply(lambda x: str(x).split()[-1] if isinstance(x, str) and len(x.split()) > 0 else None)
    
    # Считаем дубликаты по последнему слову
    duplicate_counts = last_word_series.value_counts()
    
    # Проходим по дубликатам и переименовываем их
    for last_word in duplicate_counts[duplicate_counts > 1].index:
        # Получаем индексы дубликатов
        duplicate_indices = dataframe[last_word_series == last_word].index
        
        # Переименовываем дубликаты, чтобы сохранялась уникальность
        for idx in duplicate_indices[1:]:
            dataframe.at[idx, column_name] = dataframe.at[idx, column_name]
    
    return dataframe

# Применяем функцию к данным
data = rename_duplicates_by_last_word(data, 'locality_name')

# Проверяем количество уникальных населённых пунктов после переименования дубликатов
localities_number = data['locality_name'].nunique()
localities_number
# Out:
# 330

# %%
# Выведем названия населённых пунктов после переименования
localities = data['locality_name'].unique()
localities
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
# Создадим функцию для группировки населённых пунктов
def group_locality(locality):
    
    # Если Санкт-Петербург, оставляем
    if locality == "Санкт-Петербург":
        return "Санкт-Петербург"

    # Иначе - относим к окрестностям
    return "Окрестности"

# Применяем функцию классификации
data['locality_group'] = data['locality_name'].apply(group_locality)

# Проверяем распределение по группам
locality_groups_number = data['locality_group'].value_counts()
locality_groups_number

## Применять функцию нет смысла, т.к. датасет состоит из Санкт-Петербурга и окрестностей
# Out:
# locality_group
# Санкт-Петербург    15721
# Окрестности         7978
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Зачем указывать города-милионники, если у нас датасет состоит из объектов Питера и окрестностей, что указано в ТЗ?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Действительно, это моя ошибка по невнимательности, поправил, спасибо.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Исправлено👍
#
# </div>
#
# </div>

# %%
# Построим гистограммы по каждой группе населённых пунктов
locality_groups = data['locality_group'].unique()

plt.figure(figsize=(10, 8))

# Циклом
for i, group in enumerate(locality_groups, 1):
    plt.subplot(len(locality_groups), 1, i)
    data[data['locality_group'] == group]['floors_total'].hist(bins=30, edgecolor='black')
    plt.title(f'Распределение этажей: {group}')
    plt.xlabel('Количество этажей')
    plt.ylabel('Частота')

plt.tight_layout()
plt.show()

# И здесь

# %%
# Создадим и выведем сводную таблицу с группировкой по количеству этажей и группам населённых пунктов
pivot_table_floors = data.pivot_table(values='floors_total', index='locality_group', aggfunc=['mean', 'median', 'min', 'max', 'count'])
pivot_table_floors
# Out:
#                         mean       median          min          max  \
#                 floors_total floors_total floors_total floors_total
# locality_group
# Окрестности         9.254459          5.0          1.0         60.0
# Санкт-Петербург    11.395885          9.0          1.0         52.0
#
#                        count
#                 floors_total
# locality_group
# Окрестности             7962
# Санкт-Петербург        15651

# %% [markdown]
# Из данных видно, что медианное значение Санкт-Петербурга равно 9, а вот окрестности имеют более низкую застройку - 5 этажей.
# На мой взгляд, это более точные данные для заполнения пропусков по количеству этажей.
# Применим полученные выводы на практике.

# %%
# На основе сводной таблицы заменим пропуски в исходных данных медианными значениями соответствующих групп

# Сначала выделим медианные значения для каждой группы населённых пунктов из сводной таблицы
median_floors_by_group = pivot_table_floors['median']['floors_total']

# Функция для замены пропусков на медианные значения
def fill_missing_floors(row):
    if pd.isna(row['floors_total']):
        # Если значение пропущено, берем медианное значение для группы населённого пункта
        group = row['locality_group']
        return median_floors_by_group[group]
    return row['floors_total']

# Применяем функцию к данным
data['floors_total'] = data.apply(fill_missing_floors, axis=1)

# Проверяем случаи, когда этаж больше, чем общее количество этажей, и корректируем
def check_and_correct_floor(row):
    if row['floor'] > row['floors_total']:
        return row['floors_total']
    return row['floor']

# Применяем коррекцию к столбцу floor
data['floor'] = data.apply(check_and_correct_floor, axis=1)

# Проверим, есть ли еще пропущенные значения в столбце floors_total
missing_floors_after_fill = data['floors_total'].isna().sum()

# Вывод количества пропущенных значений после заполнения
missing_floors_after_fill
# Out:
# np.int64(0)

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Пропусков в столбце floors_total изначально мало, можно сразу удалить их без потери качества данных. Если же заполнять способом, предложенным тобой, важно убедиться, что после заполнения пропусков не появилось объектов, у которых floor может быть больше floors_total
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Спасибо за уточнение, поправил.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошо👍
#
# </div>
#
# </div>

# %% [markdown]
# Возможные причины пропусков количества этажей в доме:
#
# 1. **Недостаток информации у источника**:
# - Источники данных, такие как владельцы, агентства или государственные реестры, могут не предоставлять полную информацию о зданиях. Например, частные продавцы недвижимости могут просто не знать точное количество этажей в доме, особенно если дом старый или информация отсутствует в документации.
#
# 2. **Ошибки при вводе данных**:
# - При ручном вводе данных возможны ошибки, когда оператор может пропустить или забыть заполнить поле, связанное с количеством этажей. Это может быть связано с невнимательностью, неаккуратностью или ошибками в системах ввода данных.
#
# 3. **Недоступность данных на момент сбора**:
# - В процессе сбора данных (например, при проведении оценки недвижимости) информация о количестве этажей может быть временно недоступна. Это может произойти в случае отсутствия доступа к планам здания или при невозможности уточнения на месте.
#
# 4. **Необязательность заполнения**:
# - В некоторых базах данных информация о количестве этажей может не быть обязательной для заполнения. Если это поле не является обязательным, его могут просто игнорировать при заполнении, особенно если остальная информация достаточно для выполнения текущей задачи (например, оценки квартиры или размещения объявления).
#
# 5. **Незавершенные или новые объекты**:
# - Для новостроек или объектов, которые еще находятся в стадии строительства, информация о количестве этажей может быть неизвестна или варьироваться до завершения строительства. В таких случаях пропуски возникают по причине того, что данные еще не зафиксированы.
#
# 6. **Различия в классификации**:
# - Разные системы классификации зданий могут трактовать количество этажей по-разному. Например, в некоторых странах или регионах технические этажи, мансарды или подвалы могут не считаться частью общего количества этажей. Это может приводить к тому, что данные о числе этажей либо отсутствуют, либо вводятся с неопределенностью, что может вызвать пропуски.

# %% [markdown]
# ##### Жилая площадь, квм (living_area)

# %%
# Построим гистограмму частотности по жилой площади
living_area = data['living_area'].dropna()

plt.figure(figsize=(8, 6)) 
plt.hist(living_area, bins=30, edgecolor='black', range=(0, 200)) # Ограничимся 200 квм
plt.title('Распределение по жилой площади, квм')
plt.xlabel('Жилая площадь, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Почему, работая со столбцом living_area мы используем переменную floors_total? Это вносит некую запутанность в код
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Исправил.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    👍
#
# </div>
#
# </div>

# %% [markdown]
# Наиболее часто встречающиеся значения площади находятся в промежутке между 16 и 18 квм, при этом следующий пик приходится на 27-30 квм.
# Также, заметно, что квартиры менее 16 квм встречаются также редко, как и более 60 квм.
# Предположим, что размер жилой площади зависит от следующих параметров: общая площадь и количество комнат.

# %%
# Рассчитываем среднее отношение жилой площади к общей площади
data['living_area_ratio'] = data['living_area'] / data['total_area']
median_living_area_ratio = data['living_area_ratio'].median()
median_living_area_ratio
# Out:
# np.float64(0.5678598992678503)

# %%
# Фильтруем данные
living_area_ratio = data['living_area_ratio'].dropna()

# Строим гистограмму
plt.figure(figsize=(10, 6))
plt.hist(living_area_ratio, bins=30, edgecolor='black')
plt.title('Распределение отношения жилой площади к общей площади')
plt.xlabel('Отношение жилой площади к общей площади')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Распределение получилось максимально близким к нормальному. Это говорит о том, что большинство квартир имеют схожие пропорцие жилой и общей площади.

# %%
# Заменяем значение количества комнат "0" на "1"
# data['rooms'].replace(0, 1, inplace=True)

# Фильтруем данные, чтобы убрать пропуски в жилой площади, общей площади и количестве комнат
filtered_data = data.dropna(subset=['living_area', 'total_area', 'rooms'])

# Строим scatterplot, используя цвет для обозначения количества комнат
plt.figure(figsize=(10, 6))
scatter = plt.scatter(filtered_data['total_area'], filtered_data['living_area'], 
                      c=filtered_data['rooms'], cmap='viridis', alpha=0.7)

# Добавляем цветовую шкалу для количества комнат
plt.colorbar(scatter, label='Количество комнат')

# Добавляем подписи и сетку
plt.title('Зависимость жилой площади от общей площади и количества комнат')
plt.xlabel('Общая площадь, кв.м')
plt.ylabel('Жилая площадь, кв.м')
plt.grid(True)

# Показываем график
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    Не рекомендую исправлять значения 0 на 1 в столбце rooms, по причине, что у нас в данных есть апартаменты и студии, где число комнат указывается неявно
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Думаю, если рассматривать количество комнат, как суммируемое значение, с нулевыми значениями могут возникнуть сложности. В случае, если количество комнат - категория, то лучше оставить нули.
#
# </div>

# %% [markdown]
# Заметна прямая зависимость между общей площадью и жилой площадью.
# Изучим зависимость жилой площади от общей площади и количества комнат, также, отобразим отношение жилой площади к общей.

# %%
# Создаем сводную таблицу с добавлением количества квартир
living_rooms = data.pivot_table(
    index='rooms', 
    values=['living_area', 'total_area', 'living_area_ratio'], 
    aggfunc={'living_area': 'mean', 'total_area': 'mean', 'living_area_ratio': 'mean', 'rooms': 'count'}
)

# Переименовываем столбец для количества записей
living_rooms.rename(columns={'rooms': 'total_count'}, inplace=True)

# Выводим результат
living_rooms
# Out:
#        living_area  living_area_ratio  total_count  total_area
# rooms
# 0        18.865246           0.685467          197   29.279746
# 1        17.893552           0.485989         8047   37.644669
# 2        31.736849           0.579287         7940   55.855089
# 3        47.387941           0.625302         5814   77.764580
# 4        66.983223           0.646489         1180  107.610763
# 5       100.009247           0.641377          326  161.474816
# 6       130.983636           0.668819          105  201.537619
# 7       163.564151           0.657981           59  265.325424
# 8       168.683333           0.667001           12  259.233333
# 9       190.257143           0.612299            8  305.975000
# 10      165.566667           0.645065            3  259.566667
# 11      133.900000           0.710093            2  188.900000
# 12      409.700000           0.455222            1  900.000000
# 14      195.150000           0.648695            2  304.200000
# ...

# %% [markdown]
# Видно, что в данных представлено мало квартир с более чем 5 комнатами. Отфильтруем эти данные из сводной таблицы.

# %%
living_rooms_filtered = living_rooms.query('total_count > 100')
living_rooms_filtered
# Out:
#        living_area  living_area_ratio  total_count  total_area
# rooms
# 0        18.865246           0.685467          197   29.279746
# 1        17.893552           0.485989         8047   37.644669
# 2        31.736849           0.579287         7940   55.855089
# 3        47.387941           0.625302         5814   77.764580
# 4        66.983223           0.646489         1180  107.610763
# 5       100.009247           0.641377          326  161.474816
# 6       130.983636           0.668819          105  201.537619

# %% [markdown]
# В результате видно, что у 1-2-комнатных квартир доля жилой площади к общей меньше всего, а вот у квартир с большим количеством комнат, колеблется от 0.62 до 0.67.
# Для квартир, не вошедшим в сводную таблицу, установим долю, равную медианной по всем данным.

# %%
# Фильтруем данные для квартир от 1 до 6 комнат
median_living_area_ratio_by_rooms = living_rooms_filtered.loc[1:6, 'living_area_ratio']

# Функция для замены пропусков в жилой площади
def fill_missing_living_area_with_median(row):
    if pd.isna(row['living_area']):
        # Для квартир от 1 до 6 комнат используем медианное значение для соответствующей группы комнат
        if row['rooms'] in median_living_area_ratio_by_rooms.index:
            return row['total_area'] * median_living_area_ratio_by_rooms[row['rooms']]
        # Для остальных квартир используем медианное значение area_ratio для всех данных
        else:
            median_living_area_ratio = living_rooms_filtered['living_area_ratio'].median()
            return row['total_area'] * median_living_area_ratio
    return row['living_area']

# Применяем функцию для замены пропусков
data['living_area'] = data.apply(fill_missing_living_area_with_median, axis=1)

# Проверяем, остались ли пропуски
print(data['living_area'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### Апартаменты (is_apartment)

# %% [markdown]
# Здесь всё просто - если квартира является апартаментами, то остаётся 1, если нет, вместо пропусков поставим 0.
# Пропуски здесь возникли скорее всего из-за желания сэкономить время: зачем набирать 0, если не апартаменты, если достаточно набрать 1 в обратном случае?

# %%
# Код ревьюера
data['is_apartment'].head(30)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11    False
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25    False
# 26      NaN
# 27      NaN
# 28      NaN
# 29    False
# Name: is_apartment, dtype: object

# %%
# Заменяем
data['is_apartment'].fillna(False, inplace=True)

# Проверяем, остались ли пропуски
print(data['is_apartment'].isna().sum())
# Out:
# 0
# /tmp/ipykernel_6533/3660885805.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['is_apartment'].fillna(False, inplace=True)
# /tmp/ipykernel_6533/3660885805.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['is_apartment'].fillna(False, inplace=True)

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Тип данных object, как и наличие значений False в столбце is_apartment подразумевает, что мы должны перевести тип данных в bool, а для заполнения пропусков использовать значения True и False - большинство квартир по определению не являются апартаментами, поэтому заполнить пропуски нужно значением False
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Это действительно имеет смысл. Тип данных я поменял на этапе 2.2. Замену поменял.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошо👍
#
# </div>
#
# </div>

# %% [markdown]
# ##### Площадь кухни, квм (kitchen_area)

# %% [markdown]
# Аналогично анализу жилой площади построим гистограмму частотности

# %%
# Построим гистограмму частотности по площади кухни
floors_total = data['kitchen_area'].dropna()

plt.figure(figsize=(8, 6)) 
plt.hist(floors_total, bins=30, edgecolor='black', range=(0, 40)) # Ограничимся 60 квм
plt.title('Распределение по площади кухни, квм')
plt.xlabel('Жилая площадь, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Пиковые значения частотности площади кухни: примерно 8% и 6%.
# Заметно реже встречаются кухни менее 5 и более 15 квм.
#
# Аналогично анализу живой площади, оценим зависимость количества комнат на долю площади кухни к общей площади.

# %%
# Рассчитываем среднее отношение площади кухни к общей площади
data['kitchen_area_ratio'] = data['kitchen_area'] / data['total_area']
median_kitchen_area_ratio = data['kitchen_area_ratio'].median()
median_kitchen_area_ratio
# Out:
# np.float64(0.1724137931034483)

# %%
# Фильтруем данные, где есть оба значения для корректного расчета
kitchen_area_ratio = data['kitchen_area_ratio'].dropna()

# Строим гистограмму
plt.figure(figsize=(10, 6))
plt.hist(living_area_ratio, bins=30, edgecolor='black')
plt.title('Распределение отношения жилой площади к общей площади')
plt.xlabel('Отношение жилой площади к общей площади')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Создаем сводную таблицу с добавлением количества квартир
kitchen_rooms = data.pivot_table(
    index='rooms', 
    values=['kitchen_area', 'total_area', 'kitchen_area_ratio'], 
    aggfunc={'kitchen_area': 'mean', 'total_area': 'mean', 'kitchen_area_ratio': 'mean', 'rooms': 'count'}
)

# Переименовываем столбец для количества записей
kitchen_rooms.rename(columns={'rooms': 'total_count'}, inplace=True)

# Выводим результат
kitchen_rooms
# Out:
#        kitchen_area  kitchen_area_ratio  total_count  total_area
# rooms
# 0               NaN                 NaN          197   29.279746
# 1          9.550118            0.249906         8047   37.644669
# 2          9.979584            0.174163         7940   55.855089
# 3         11.308580            0.140928         5814   77.764580
# 4         13.664033            0.124031         1180  107.610763
# 5         18.367649            0.113455          326  161.474816
# 6         21.048763            0.104150          105  201.537619
# 7         21.998077            0.091932           59  265.325424
# 8         24.866667            0.091708           12  259.233333
# 9         25.071429            0.075054            8  305.975000
# 10        22.866667            0.088013            3  259.566667
# 11        12.600000            0.066855            2  188.900000
# 12       112.000000            0.124444            1  900.000000
# ...

# %% [markdown]
# Аналогично ситуации с жилой площадью, уберём из выблорки квартиры с более чем 5 комнатами (их количество < 100)

# %%
kitchen_rooms_filtered = kitchen_rooms.query('total_count > 100')
kitchen_rooms_filtered
# Out:
#        kitchen_area  kitchen_area_ratio  total_count  total_area
# rooms
# 0               NaN                 NaN          197   29.279746
# 1          9.550118            0.249906         8047   37.644669
# 2          9.979584            0.174163         7940   55.855089
# 3         11.308580            0.140928         5814   77.764580
# 4         13.664033            0.124031         1180  107.610763
# 5         18.367649            0.113455          326  161.474816
# 6         21.048763            0.104150          105  201.537619

# %% [markdown]
# У 1-2-комнатных квартир доля площади у кухне к общей больше всего, вместе с тем, она уменьшается с увеличением количества комнат. Это может говорить о том, что при свободе, дающей просторным жильём, люди обычно отдают приоритет другим активностям, нежели готовке. Или чем ещё можно заниматься на кухне?
# С другой стороны, так как доля жилой площади у квартир, в которых больше 2 комнат, сильно не растёт, можно предположить, что освободившееся пространство используется под балконы/лоджии/кладовые и технические помещения, которые не считаются жилыми.
#
# Больше площади жилья - больше возможностей для полноценной жизни.
#
# Заполним пропуски медианными значений каждой группы по количеству комнат:

# %%
# Фильтруем данные для квартир от 1 до 6 комнат
median_kitchen_area_ratio_by_rooms = kitchen_rooms_filtered.loc[1:6, 'kitchen_area_ratio']

# Функция для замены пропусков в площади кухни.
def fill_missing_kitchen_area_with_median(row):
    if pd.isna(row['kitchen_area']):
        # Для квартир от 1 до 6 комнат используем медианное значение для соответствующей группы комнат
        if row['rooms'] in median_kitchen_area_ratio_by_rooms.index:
            return row['total_area'] * median_kitchen_area_ratio_by_rooms[row['rooms']]
        # Для остальных квартир используем медианное значение area_ratio для всех данных
        else:
            median_kitchen_area_ratio = kitchen_rooms_filtered['kitchen_area_ratio'].median()
            return row['total_area'] * median_kitchen_area_ratio
    return row['kitchen_area']

# Применяем функцию для замены пропусков
data['kitchen_area'] = data.apply(fill_missing_kitchen_area_with_median, axis=1)

# Проверяем, остались ли пропуски
print(data['kitchen_area'].isna().sum())
# Out:
# 0

# %% [markdown]
# Возможные причины пропусков по площади кухни и жилой площади
#
# 1. **Отсутствие обязательного требования указывать эти данные**
# - В некоторых базах данных или при подаче объявлений на продажу/аренду недвижимости, такие параметры, как площадь кухни и жилая площадь, могут не быть обязательными для заполнения.
#
# 2. **Неизвестные или затрудненные замеры**
# - Жилая площадь и площадь кухни могут быть сложными для точного измерения, особенно в старых зданиях с нетипичной планировкой, встроенной мебелью или перепланировками. Иногда владельцы недвижимости могут не знать точных размеров этих зон, и если у них нет доступных планов БТИ или замеров, они могут просто не указывать эти данные.
#
# 3. **Реконструкция и перепланировка**
# - Если квартира или дом прошли перепланировку (например, объединили комнаты, расширили кухню за счет других помещений), данные о жилой площади и кухне могут быть не обновлены. Владелец может затрудняться предоставить точные замеры после изменений, особенно если перепланировка была проведена неофициально.
#
# 4. **Использование общей площади как основного показателя**
# - В объявлениях часто акцентируется внимание на общей площади квартиры или дома, а жилая площадь и площадь кухни могут не считаться важными для публикации. Это особенно актуально для недвижимости с маленькими кухнями, когда продавцы предпочитают не указывать такие данные, чтобы не отпугнуть покупателей.
#
# 5. **Стандартизация данных в базах**
# - В некоторых случаях данные о жилой площади или кухне могут отсутствовать в государственных реестрах или базах данных, откуда агентства получают информацию. Такие базы могут содержать лишь общую площадь или планировку, но не конкретные размеры всех помещений.
#
# 6. **Отсутствие четкого определения "жилой площади"**
# - В разных странах и регионах существуют различные определения жилой площади. Например, могут быть разногласия в том, считать ли балконы, веранды или подсобные помещения частью жилой зоны. В случае, если нет единого стандарта, продавцы или агенты могут избегать указывать эти данные, чтобы не допустить ошибки.
#
# 7. **Лень или невнимательность при заполнении**
# - Пропуски могут возникнуть просто из-за человеческого фактора: недочета, невнимательности или нежелания вносить всю информацию. Если поле не обязательное, его могут пропустить, особенно при заполнении большого количества объявлений.
#
# 8. **Отсутствие доступных планов и документации**
# - В некоторых случаях у владельца недвижимости может просто не быть доступа к официальным планам с размерами жилой зоны и кухни. Это характерно для старого жилого фонда или недвижимости, которая была куплена или получена по наследству без официальной документации.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Как альтернатива, мы можем использовать метод медианного коэффициента - для этого нужно найти **соотношение медианной общей площади к медианной жилой**. А затем, заполнить пропуски в столбце `living_area` **отношением общей площади к найденному соотношению**.
#
#   Со столбцом `kitchen_area` можно поступить так же, как со столбцом `living_area`.
#
#
# </div>

# %% [markdown]
# ##### Число балконов (balcony)

# %%
# Выведем варианты
data['balcony'].unique()
# Out:
# array([nan,  2.,  0.,  1.,  5.,  4.,  3.])

# %% [markdown]
# Заменим пропуски количества балконов на 0 и переведём данные в столбце в целочисленный тип, ведь невозможно не целое количество балконов в квартире

# %%
# Заменяем
data['balcony'].fillna(0, inplace=True)

# Меняем тип данных
data['balcony'] = data['balcony'].astype('int')

# Проверяем, остались ли пропуски
print(data['balcony'].isna().sum())
# Out:
# 0
# /tmp/ipykernel_6533/731026778.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['balcony'].fillna(0, inplace=True)

# %% [markdown]
# Пропуски количества балконов похожи на аналогичные пропускам по апартаментам. Предположительная причина - экономия времени на ввод данных.

# %% [markdown]
# ##### Название населённого пункта (locality_name)

# %% [markdown]
# Пропуски были заменены на этапе **2.1.2 Этажей в доме (floors_total)**

# %% [markdown]
# Возможные причины пропусков названий населённых пунктов:
#
# 1. **Отсутствие информации на момент сбора данных**
# - Источники данных, такие как владельцы недвижимости или агентства, могут просто не знать точное название населенного пункта, особенно если объект находится в отдаленном или недавно застроенном районе. Например, если новый жилой комплекс построен на окраине города, название населенного пункта может быть не определено до момента официальной регистрации.
#
# 2. **Ошибки или пропуски при вводе данных**
# - Человеческий фактор, такой как невнимательность при вводе данных, может привести к тому, что название населенного пункта будет забыто или пропущено. Особенно это часто происходит при заполнении большого объема информации вручную.
#
# 3. **Населенные пункты на границах или в спорных территориях**
# - Объекты, расположенные на границе между двумя населёнными пунктами, могут не иметь четкой привязки к одному конкретному населённому пункту. В таких случаях может возникнуть неопределенность, и эта информация может остаться незаполненной. Это также относится к спорным или плохо документированным территориям, где административные границы нечетко определены.
#
# 4. **Неполная или устаревшая база данных**
# - Базы данных могут содержать устаревшие или неполные данные о населённых пунктах, особенно если это касается удалённых или малонаселённых регионов. Например, если база данных не была обновлена с учетом изменений в административном делении, информация может быть неполной.
#
# 5. **Новая застройка или нерегулярные поселения**
# - Если объект недвижимости расположен в районе нового строительства или в недавно организованном населённом пункте, информация о нём может отсутствовать до официальной регистрации населенного пункта. В некоторых случаях это может касаться и стихийных поселений или районов, которые ещё не имеют официального статуса.
#
# 6. **Неправильная классификация объекта**
# - Некоторые объекты недвижимости могут быть расположены за пределами населенных пунктов (например, дачи или сельские участки), и в таких случаях может возникнуть вопрос о том, следует ли указывать название ближайшего населенного пункта. Иногда такие объекты ошибочно остаются без привязки к конкретному населённому пункту.
#
# 7. **Использование автоматизированных систем ввода данных**
# - Если данные о населённых пунктах вводятся с помощью автоматизированных систем или инструментов геокодирования, могут возникать ошибки при определении населённого пункта. Например, система может не распознать объект или неверно сопоставить его с административной территорией.
#
# 8. **Изменение административных границ**
# - Пропуски могут возникать в случаях, когда административные границы населённых пунктов изменяются. Например, если несколько населенных пунктов объединяются в один или наоборот — крупный населенный пункт делится на несколько районов, информация о принадлежности объекта к конкретному населённому пункту может не обновиться своевременно.
#
# 9. **Недоступность или скрытие данных**
# - В некоторых случаях информация о населённых пунктах может быть утеряна или скрыта по различным причинам. Например, если продавец недвижимости намеренно скрывает местоположение объекта для повышения интереса или если данные изначально поступили с неполной информацией о местоположении.

# %% [markdown]
# ##### Расстояние до аэропорта, м (airports_nearest)

# %%
# Построим гистограмму частотности по расстоянию к аэропорту
airports_nearest = data['airports_nearest'].dropna()

plt.figure(figsize=(8, 6)) 
plt.hist(airports_nearest, bins=30, edgecolor='black')
plt.title('Распределение по расстоянию к аэропорту, м')
plt.xlabel('Расстояние к аэропорту, м')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Чаще всего встречаются расстояния от 16 до 24 км до аэропорта.
# Исследуем удалённость квартиры от аэропорта в зависимости от группы населённого пункта.

# %%
# Создадим и выведем сводную таблицу
pivot_table_airports_nearest = data.pivot_table(values='airports_nearest', index='locality_group', aggfunc=['mean', 'median', 'min', 'max', 'count'])
pivot_table_airports_nearest
# Out:
#                             mean           median              min  \
#                 airports_nearest airports_nearest airports_nearest
# locality_group
# Окрестности         33429.804839          26599.0           9294.0
# Санкт-Петербург     28046.186237          26757.5              0.0
#
#                              max            count
#                 airports_nearest airports_nearest
# locality_group
# Окрестности              84869.0             2521
# Санкт-Петербург          54784.0            15636

# %% [markdown]
# Интересно, что есть квартиры с 0 расстоянием до аэропорта, похоже жилой комплекс или дом располагается прямо в аэропорту.
# Также заметно, что хоть и среднее значение расстояния до аэропорта в Санкт-Петербурге меньше, чем в остальных, однако медианные значения не указывают на существенную разницу. Возможно, на среднее как раз и повлияли случаи с нулевым расстоянием.
#
# Посмотрим гистограммы частотности удалённости аэропорта для каждой группы населённых пунктов.

# %%
# Построим гистограммы по каждой группе населённых пунктов
locality_groups = data['locality_group'].unique()

plt.figure(figsize=(10, 8))

# Циклом
for i, group in enumerate(locality_groups, 1):
    plt.subplot(len(locality_groups), 1, i)
    data[data['locality_group'] == group]['airports_nearest'].hist(bins=30, edgecolor='black')
    plt.title(f'Распределение удалённости аэропорта: {group}')
    plt.xlabel('Расстояние до аэропорта, м')
    plt.ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# Любопытно, что в Санкт-Петербурге распределение стремится к нормальному, а вот в окрестностях явно присутствют выбросы.
# Так как страна у нас большая и многие населённые пункты, особенно малые, могут находиться и на расстоянии более чем 60 км, предполагаю, что пропуски расстояния до аэропорта нельзя заполнить.
#
# Есть подозрение, что пропуски расстояний до аэропорта совпадают с пропусками расстояний до городских центров, близости парков, количества парков в радиусе 3 км, близости прудов и количества прудов в радиусе 3 км.
# Проверим это.

# %%
# Соберём категории в список для удобства
columns_to_check = ['airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest']

# Сначала выведем общее количество пропусков по группам населённых пунктов и выбранным категориям
missing_counts = data.pivot_table(index='locality_group', values=columns_to_check, aggfunc=lambda x: x.isnull().sum())
missing_counts
# Out:
#                  airports_nearest  cityCenters_nearest  parks_around3000  \
# locality_group
# Окрестности                  5457                 5458              5457
# Санкт-Петербург                85                   61                61
#
#                  parks_nearest  ponds_around3000  ponds_nearest
# locality_group
# Окрестности               7183              5457           6851
# Санкт-Петербург           8437                61           7738

# %%
# А теперь посчитаем количество совпадающих строк в каждой из категории
print(data[columns_to_check].isnull().all(axis=1).sum())
# Out:
# 5518

# %% [markdown]
# Подозрение оказалось верным - 5,5 тысяч строк имеют пропуски по выбранным категориям.
# Вероятно, они возникли по технической причине. Похоже на то, что в малых населённых пунктах и других городах просто не учитываются эти категории при заполнении.
# Предполагаю, что заполнять средним или медианным значениями данные параметры будет плохой практикой, поэтому оставлю их пустыми, тем более, они не учитываются дальше в задании.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#
#
#
#    Действительно, работая с картографическими данными нужно быть очень осторожным - размах выборки большой, поэтому заполнение пропусков может привести к тому, что данные окажутся неактуальными - стоит оставить пропуски без изменений. К тому же, согласно ТЗ, в дальнейшем анализе они не участвуют
#
# </div>

# %%
# Выведем количество пропущенных значений для каждого столбца
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# locality_group              0
# living_area_ratio        1903
# kitchen_area_ratio       2278
# dtype: int64

# %% [markdown]
# Пропуски в столбцах 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest' могут возникать по следующим причинам:
#
# 1. **Отсутствие инфраструктуры**
# - **Аэропорты, городские центры, парки, пруды** могут просто не существовать в непосредственной близости от объекта недвижимости. Например, если дом находится в сельской или удаленной местности, рядом может не быть аэропортов, парков или прудов. В таких случаях это поле остается пустым, так как данные об этих объектах попросту отсутствуют.
#
# 2. **Недостаток данных о географическом местоположении**
# - Пропуски могут быть связаны с отсутствием точных координат объекта недвижимости. Без этих данных системы не могут корректно определить расстояние до ближайших объектов инфраструктуры (аэропортов, городских центров, парков, прудов). Это часто происходит, если недвижимость зарегистрирована некорректно или без точных географических данных.
#
# 3. **Технические ошибки при сборе данных**
# - Пропуски могут возникать из-за ошибок при сборе данных, например, сбои в системе GPS, неправильное сопоставление объектов с их местоположением или некорректное импортирование данных в базу. В таких случаях информация о ближайших объектах инфраструктуры не добавляется в базу данных, оставляя поля пустыми.
#
# 4. **Необязательные поля**
# - Некоторые системы, собирающие данные, могут не считать информацию о ближайших аэропортах, парках и других объектах инфраструктуры критически важной.
#
# 5. **Изменение окружающей инфраструктуры**
# - Пропуски могут возникать, если данные о ближайших объектах инфраструктуры устарели. Например, парк или аэропорт могли закрыться, а новые объекты еще не были добавлены в систему. Это может происходить в районах с активной застройкой или реконструкцией, где объекты инфраструктуры появляются и исчезают относительно быстро.
#
# 6. **Отсутствие достоверных источников данных**
# - В некоторых районах могут отсутствовать надежные источники данных о ближайших инфраструктурных объектах. Если база данных не имеет доступа к точным сведениям о расположении парков, аэропортов или других объектов, эта информация просто не будет доступна, что вызовет пропуски.
#
# 7. **Неоднородность данных**
# - Когда данные собираются из различных источников (например, данные из государственных реестров, частных агентств, спутниковых снимков), может возникать неоднородность данных. Некоторые источники могут предоставлять информацию о парках и городских центрах, но не о прудах или аэропортах, что приводит к пропускам в отдельных столбцах.
#
# 8. **Ограниченные возможности анализа данных в удалённых районах**
# - Для объектов, находящихся в удалённых или малоразвитых районах, системы геоанализа могут сталкиваться с трудностями при определении ближайших объектов инфраструктуры. Это может быть связано с недостатком картографической информации или слабым покрытием спутниковых снимков. В таких случаях информация может быть недоступна, и данные остаются пустыми.
#
# 9. **Человеческий фактор**
# - Как и во многих других случаях, ошибки ввода данных могут также привести к пропускам. Если оператор не посчитал важным или просто забыл указать расстояние до ближайших инфраструктурных объектов, эти данные останутся незаполненными.

# %% [markdown]
# #### Обработка типов данных

# %%
# Ещё раз выведем инфо датафрейма
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  float64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
# Выведем первые 10 строк first_day_exposition, чтобы посмотреть на структуру столбца
data['first_day_exposition'].head(10)
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# 5    2018-09-10T00:00:00
# 6    2017-11-02T00:00:00
# 7    2019-04-18T00:00:00
# 8    2018-05-23T00:00:00
# 9    2017-02-26T00:00:00
# Name: first_day_exposition, dtype: object

# %%
# Приведём к типу datetime поле first_day_exposition, т.к. оно содержит даты.
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

# %% [markdown]
# Значения в столбце is_apartment бывают только 1 и 0, это фактически булевый тип данных, где 1 означает "Да" (апартаменты), а 0 — "Нет" (не апартаменты).
# В таком случае, лучший выбор — преобразовать этот столбец в тип bool. Преобразование в булевый тип улучшит читаемость данных и уменьшит объем памяти, который используется для хранения этой информации.

# %%
# Преобразуем is_apartment в тип bool
data['is_apartment'] = data['is_apartment'].astype(bool)

# %%
# Количество этажей не может быть не целым, поэтому приводим к целому числу
data['floors_total'] = data['floors_total'].astype('int')

# %%
# locality_name и locality_group - это поля, которые содержат категории (населённые пункты и их группы). Приведём их к типу category
data['locality_name'] = data['locality_name'].astype('category')
data['locality_group'] = data['locality_group'].astype('category')

# %%
# Ещё раз выведем инфо датафрейма
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  float64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# Взглянем на уникальные значения высоты потолков. В задании указали, что они могут быть неадекватными.

# %%
data.query('ceiling_height > 5').sort_values(by='ceiling_height', ascending=False)['ceiling_height']
# Out:
# 22869    100.0
# 3148      32.0
# 22336     32.0
# 21377     27.5
# 20478     27.0
# 22938     27.0
# 17857     27.0
# 21824     27.0
# 10773     27.0
# 4876      27.0
# 5807      27.0
# 5246      27.0
# 5669      26.0
# 11285     25.0
# 18545     25.0
# 355       25.0
# 9379      25.0
# 14382     25.0
# 6246      25.0
# 4643      25.0
# 5076      24.0
# 20507     22.6
# 17496     20.0
# 15061     14.0
# 22309     10.3
# 5863       8.3
# 3474       8.0
# 15743      8.0
# 17442      8.0
# 20264      6.0
# 21227      5.8
# 1388       5.6
# 7578       5.5
# 1026       5.3
# 12628      5.3
# 464        5.2
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Есть квартиры с высотой 5 и 8 метров. В это сложно поверить, как и в квартиры с высотой больше 10 метров. Даже 100 метров есть. Даже если предположить, что в данных присутствуют двухэтажные квартиры или коммерческие помещения 100 метров - неадекватная высота.
# Вычистим данные, разделив все высоты больше 10 метров на 10.

# %%
# Функция для очистки данных о высоте потолков
def clean_ceiling_height(height):
    if height > 10:
        return height / 10
    return height

# Применяем функцию к столбцу с высотой потолков
data['ceiling_height'] = data['ceiling_height'].apply(clean_ceiling_height)

# %%
# Проверим результаты
data.query('ceiling_height > 5').sort_values(by='ceiling_height', ascending=False)['ceiling_height']
# Out:
# 22869    10.0
# 5863      8.3
# 3474      8.0
# 17442     8.0
# 15743     8.0
# 20264     6.0
# 21227     5.8
# 1388      5.6
# 7578      5.5
# 1026      5.3
# 12628     5.3
# 464       5.2
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Проверь, не пропущен ли блок кода с делением на 10
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Блок кода был, видимо удалил случайно. Вернул на место.
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
# Рекомендую ознакомиться с методом update для решения данной задачи - он работает быстрее конструкции c if
#
# </div>
#
#
# </div>

# %%
# Код ревьюера
#data.update(data[(data['ceiling_height'] >= 20) & (data['ceiling_height'] <= 36)]['ceiling_height']/10)
#data['ceiling_height'].unique()

# %% [markdown]
# Предполагаю, что пропуски высоты потолков можно заполнить чаще встречающимся, типичными значениями, которые если и будут отличаться от реальных, то не сильно.
# Для этого, построим гистограмму распределения.

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# #### Цена квадратного метра

# %%
# Добавляем столбец "цена квадратного метра"
data['price_per_sqm'] = (data['last_price'] / data['total_area']).round(2)

# Отобразим первые 5 строк
data[['last_price', 'total_area', 'price_per_sqm']].head()
# Out:
#    last_price  total_area  price_per_sqm
# 0  13000000.0       108.0      120370.37
# 1   3350000.0        40.4       82920.79
# 2   5196000.0        56.0       92785.71
# 3  64900000.0       159.0      408176.10
# 4  10000000.0       100.0      100000.00

# %% [markdown]
# #### День недели публикации объявления

# %%
# Добавляем день недели публикации
data['weekday_of_exposition'] = data['first_day_exposition'].dt.weekday

# Покажем 5 строк
data[['first_day_exposition', 'weekday_of_exposition']].head()
# Out:
#   first_day_exposition  weekday_of_exposition
# 0           2019-03-07                      3
# 1           2018-12-04                      1
# 2           2015-08-20                      3
# 3           2015-07-24                      4
# 4           2018-06-19                      1

# %% [markdown]
# #### Месяц публикации объявления

# %%
# Добавляем месяц публикации
data['month_of_exposition'] = data['first_day_exposition'].dt.month

# Покажем 5 строк
data[['first_day_exposition', 'month_of_exposition']].head()
# Out:
#   first_day_exposition  month_of_exposition
# 0           2019-03-07                    3
# 1           2018-12-04                   12
# 2           2015-08-20                    8
# 3           2015-07-24                    7
# 4           2018-06-19                    6

# %% [markdown]
# #### Год публикации объявления

# %%
# Добавляем год публикации
data['year_of_exposition'] = data['first_day_exposition'].dt.year

# Покажем 5 строк
data[['first_day_exposition', 'year_of_exposition']].head()
# Out:
#   first_day_exposition  year_of_exposition
# 0           2019-03-07                2019
# 1           2018-12-04                2018
# 2           2015-08-20                2015
# 3           2015-07-24                2015
# 4           2018-06-19                2018

# %% [markdown]
# #### Тип этажа квартиры

# %%
# Определяем функцию для классификации этажа
def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

# Применяем функцию к DataFrame и создаем новый столбец с типом этажа
data['floor_type'] = data.apply(floor_type, axis=1)

# Проверяем первые 10 строк
data[['floor', 'floors_total', 'floor_type']].head(5)
# Out:
#    floor  floors_total floor_type
# 0    8.0            16     другой
# 1    1.0            11     первый
# 2    4.0             5     другой
# 3    9.0            14     другой
# 4   13.0            14     другой

# %% [markdown]
# #### Расстояние до центра города в км

# %%
# Преобразуем расстояние до центра города из метров в километры и округляем до ближайших целых значений
data['cityCenters_nearest_km'] = (data['cityCenters_nearest'] / 1000).round()

# Проверяем первые несколько строк
data[['cityCenters_nearest', 'cityCenters_nearest_km']].head()
# Out:
#    cityCenters_nearest  cityCenters_nearest_km
# 0              16028.0                    16.0
# 1              18603.0                    19.0
# 2              13933.0                    14.0
# 3               6800.0                     7.0
# 4               8098.0                     8.0

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Исследуем параметры

# %% [markdown]
# Построим гистограммы частотности по следующим параметрам:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка

# %% [markdown]
# ##### Общая площадь (total_area)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['total_area'], bins=30, edgecolor='black')
plt.title('Распределение по общей площади')
plt.xlabel('Общая площадь, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение общей площади по всем квартирам
data['total_area'].median()
# Out:
# np.float64(52.0)

# %% [markdown]
# Распределение не похоже на нормальное из-за наличия квартир площадью более 200 квадратных метров.
# Квартиры площадью менее 100 квадратных метров можно отнести к массовому сегменту, а остальные - к сегменту дорогой элитной недвижимости.
# Так и разделим данные, а потом можно будет анализировать сегменты по отдельности.
# Также посмотрим, изменится ли медианное значение общей площади.

# %%
# Создадим функцию для группировки по общей площади
def group_total_area(total_area):
    
    # Если площадь менее 100 квм, то относим к массовому сегменту
    if total_area <= 100:
        return "массовый сегмент"

    # Иначе, к дорогой недвижимости
    return "дорогая недвижимость"

# Применяем обновлённую функцию классификации
data['total_area_group'] = data['total_area'].apply(group_total_area)

# %%
# Посчитаем количество квартир по сегментам
total_area_grouped = data.pivot_table(index='total_area_group', values='total_area', aggfunc='count')
total_area_grouped
# Out:
#                       total_area
# total_area_group
# дорогая недвижимость        1836
# массовый сегмент           21863

# %%
# Посчитаем долю дорогой недвижимости от общего количества квартир
luxury_total_area_count = data.query('total_area_group == "дорогая недвижимость"')['total_area'].count()
total_area_count = data['total_area'].count()
print(f'Дорогая недвижимость составляет всего {luxury_total_area_count/total_area_count * 100:.2f}% от общего количества квартир')
# Out:
# Дорогая недвижимость составляет всего 7.75% от общего количества квартир

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Здесь код упал с ошибкой : NameError: name 'luxury' is not defined - исправь ее, и продолжим проверку
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Починил.
#
# </div>

# %% [markdown]
# А теперь, построим гистограммы частотности для обоих сегментов и посчитаем медианы:

# %%
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "массовый сегмент"')['total_area'], bins=30, edgecolor='black')
plt.title('Распределение по общей площади массового сегмента')
plt.xlabel('Общая площадь массового сегмента, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение площади квартиры в массовом сегменте
data.query('total_area_group == "массовый сегмент"')['total_area'].median()
# Out:
# np.float64(49.9)

# %% [markdown]
# Распределение квартир в массовом сегменте стало больше походить на нормальное, а медиана уменьшилась. Благодаря классификации по сегментам, мы стали точнее в своих выводах.

# %%
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "дорогая недвижимость"')['total_area'], bins=30, edgecolor='black')
plt.title('Распределение по общей площади дорогих квартир')
plt.xlabel('Общая площадь дорогих квартир, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение площади квартиры по дорогим квартирам
data.query('total_area_group == "дорогая недвижимость"')['total_area'].median()
# Out:
# np.float64(126.25)

# %% [markdown]
# По распределению площадей в дорогом сегменте видно, что чем больше площадь, тем реже она встречается, что закономерно. Медиана пришлась на 126,25 кв метров.
#
# Благодаря сегментации, мы исключили взаимное влияние дорогого сегмента на массовый и теперь можем делать более точные выводы.

# %% [markdown]
# ##### Жилая площадь (living_area)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['living_area'], bins=30, edgecolor='black')
plt.title('Распределение по жилой площади')
plt.xlabel('Жилая площадь, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение жилой площади по всем квартирам
data['living_area'].median()
# Out:
# np.float64(30.0)

# %% [markdown]
# Распределение по жилой площади напоминает распределение по общей. Построим гистограммы и посчитаем медианы с учётом сегментации по общей площади.

# %%
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "массовый сегмент"')['living_area'], bins=30, edgecolor='black')
plt.title('Распределение по жилой площади массового сегмента')
plt.xlabel('Жилая площадь массового сегмента, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение жилой площади квартиры в массовом сегменте
data.query('total_area_group == "массовый сегмент"')['living_area'].median()
# Out:
# np.float64(29.1)

# %%
# Распределение жилой площади по дорогой недвижимости
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "дорогая недвижимость"')['living_area'], bins=30, edgecolor='black')
plt.title('Распределение по жилой площади дорогих квартир')
plt.xlabel('Жилая площадь дорогих квартир, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение жилой площади дорогих квартир
data.query('total_area_group == "дорогая недвижимость"')['living_area'].median()
# Out:
# np.float64(76.25)

# %% [markdown]
# Любопытно, что в дорогом сегменте встречаются квартиры с жилой площадью меньше 50 кв метров. Это говорит о том, что не всегда жилая площадь прямо пропорциональна общей площади, то есть не всегда при увеличении размеров общей площади будет увеличиваться жилая площадь.

# %% [markdown]
# ##### Площадь кухни (kitchen_area)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['kitchen_area'], bins=30, edgecolor='black')
plt.title('Распределение по площади кухни')
plt.xlabel('Площадь кухни, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение площади кухни по всем квартирам
data['kitchen_area'].median()
# Out:
# np.float64(9.1)

# %%
# Построим гистограмму распределения площади кухни по массовому сегменту
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "массовый сегмент"')['kitchen_area'], bins=30, edgecolor='black')
plt.title('Распределение по площади кухни массового сегмента')
plt.xlabel('Площадь кухни массового сегмента, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение площади кухни массового сегмента
data.query('total_area_group == "массовый сегмент"')['kitchen_area'].median()
# Out:
# np.float64(9.0)

# %%
# Построим гистограмму распределения площади кухни по дорогой недвижимости
plt.figure(figsize=(8, 6))
plt.hist(data.query('total_area_group == "дорогая недвижимость"')['kitchen_area'], bins=30, edgecolor='black')
plt.title('Распределение по площади кухни дорогих квартир')
plt.xlabel('Площадь кухни дорогих квартир, квм')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем медианное значение площади кухни дорогих квартир
data.query('total_area_group == "дорогая недвижимость"')['kitchen_area'].median()
# Out:
# np.float64(17.0)

# %% [markdown]
# Что характерно, площадь кухни в массовом сегменте примерно в 2 раза меньше, чем в сегменте дорогой недвижимости.
# Распределения площадей по сегментам выглядят похожим образом и говорят о том, что чаще всего встречаются медианные значения.

# %% [markdown]
# ##### Цена объекта (last_price)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['last_price'], bins=30, edgecolor='black')
plt.title('Распределение по цене объекта')
plt.xlabel('Цена объекта')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# График получился довольно странным. Похоже, есть серьёзные выбросы, влияние на отображение.
# Исследуем варианты цен и к чему они относятся.

# %%
# Выведем 5 максимальных и 5 минимальных значений цены
data.sort_values(by='last_price', ascending=False)['last_price']
# Out:
# 12971    763000000.0
# 19540    420000000.0
# 14706    401300000.0
# 1436     330000000.0
# 15651    300000000.0
#             ...
# 16219       450000.0
# 16274       440000.0
# 14911       430000.0
# 17456       430000.0
# 8793         12190.0
# Name: last_price, Length: 23699, dtype: float64

# %%
# Выведем сводную таблицу по сегментам общей площади, что мы создали ранее и ценам
pivot_table_last_price = data.pivot_table(values='last_price', index='total_area_group', aggfunc=['mean', 'median', 'min', 'max', 'count'])
pivot_table_last_price
# Out:
#                               mean      median        min          max  \
#                         last_price  last_price last_price   last_price
# total_area_group
# дорогая недвижимость  2.382506e+07  15784217.5    12190.0  763000000.0
# массовый сегмент      5.090123e+06   4450000.0   430000.0   53000000.0
#
#                           count
#                      last_price
# total_area_group
# дорогая недвижимость       1836
# массовый сегмент          21863

# %% [markdown]
# Любопытно, что минимальная цена попала в сегмент дорогой недвижимости и равна 12190. Скорее всего, цена была записана в тысячах и не хватает трёх нулей для полноценной записи.
#
# Цены по 420 и 763 миллиона рублей за квартиру меня не смущают, исходя из современных аппетитов застройщиков. Всё может быть.
#
# В массовом сегменте минимальные и максимальные цены соответствуют действительности.
# Где-нибудь в Воркуте можно и за 400000 квартиру купить, а в Белогороде или Курской области ещё дешевле.

# %%
# Домножим на 1000 цену 12190
data.loc[(data['last_price'] == 12190), 'last_price'] *= 1000

# Выведем 5 максимальных и 5 минимальных значений цены для проверки
data.sort_values(by='last_price', ascending=False)['last_price']
# Out:
# 12971    763000000.0
# 19540    420000000.0
# 14706    401300000.0
# 1436     330000000.0
# 15651    300000000.0
#             ...
# 17676       450000.0
# 16219       450000.0
# 16274       440000.0
# 17456       430000.0
# 14911       430000.0
# Name: last_price, Length: 23699, dtype: float64

# %% [markdown]
# Разброс квартир всё ещё остаётся довольно большим для корректного отображения. Сегментируем квартиры по следующим признакам цены:
# - до 10 млн
# - от 10 до 100 млн
# - свыше 100 млн

# %%
# Создадим функцию для группировки по цене
def group_last_price(last_price):
    
    # Если цена меньше 10 млн
    if last_price <= 10000000:
        return "до 10 млн"
    
    # Если цена больше 10 млн и меньше 100 млн
    if last_price > 10000000 and last_price <= 100000000:
        return "от 10 до 100 млн"

    # Иначе, свыше 100 млн
    return "свыше 100 млн"

# Применяем обновлённую функцию классификации
data['last_price_group'] = data['last_price'].apply(group_last_price)

# %%
# Посчитаем количество квартир по сегментам
last_price_grouped = data.pivot_table(index='last_price_group', values='last_price', aggfunc='count')
last_price_grouped
# Out:
#                   last_price
# last_price_group
# до 10 млн              20977
# от 10 до 100 млн        2685
# свыше 100 млн             37

# %% [markdown]
# Любопытно, что в группу свыше 100 млн вошло всего 37 квартир.
# Выведем их.

# %%
data.query('last_price_group == "свыше 100 млн"')[['rooms', 'living_area','total_area', 'last_price', 'total_area_group']]
# Out:
#        rooms  living_area  total_area   last_price      total_area_group
# 793        4   250.000000       310.0  135000000.0  дорогая недвижимость
# 1026       5   190.000000       310.0  155000000.0  дорогая недвижимость
# 1188       6   188.700000       290.6  118000000.0  дорогая недвижимость
# 1300       5   162.000000       280.0  120000000.0  дорогая недвижимость
# 1436       3    95.000000       190.0  330000000.0  дорогая недвижимость
# 1928       4   163.500000       224.5  125000000.0  дорогая недвижимость
# 2243       5   194.978536       304.0  130278280.0  дорогая недвижимость
# 2536       4   131.000000       242.4  159984000.0  дорогая недвижимость
# 3117       7   404.708737       631.0  140000000.0  дорогая недвижимость
# 4996       4    67.200000       124.5  124000000.0  дорогая недвижимость
# 5893       6   334.409592       500.0  230000000.0  дорогая недвижимость
# 7543       5   187.900000       307.8  130000000.0  дорогая недвижимость
# ...

# %% [markdown]
# Все эти квартиры относятся к дорогой недвижимости, имеют более чем в 2 раза большую медианной общую площадь.
# Хорошо, что мы выделили эти квартиры в отдельный сегмент.

# %%
# Построим гистограмму распределения стоимости квартир до 10 млн
plt.figure(figsize=(8, 6))
plt.hist(data.query('last_price_group == "до 10 млн"')['last_price'], bins=30, edgecolor='black')
plt.title('Распределение по стоимости квартир до 10 млн')
plt.xlabel('Стоимость квартир до 10 млн')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Удачное распределение для массового сегмента. Квартиры дешевле 10 млн легче отнести именно к массовому сегменту.

# %%
# Построим гистограмму распределения стоимости квартир от 10 до 100 млн
plt.figure(figsize=(8, 6))
plt.hist(data.query('last_price_group == "от 10 до 100 млн"')['last_price'], bins=30, edgecolor='black')
plt.title('Распределение по стоимости квартир от 10 до 100 млн')
plt.xlabel('Стоимость квартир от 10 до 100 млн')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Построим гистограмму распределения стоимости квартир свыше 100 млн
plt.figure(figsize=(8, 6))
plt.hist(data.query('last_price_group == "свыше 100 млн"')['last_price'], bins=30, edgecolor='black')
plt.title('Распределение по стоимости квартир свыше 100 млн')
plt.xlabel('Стоимость квартир свыше 100 млн')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# Распределение сегментов от 10 до 100 млн и свыше 100 млн похоже и отображает скорее исключения из общей картины. Премиум-недвижимость рассчитана на ограниченный круг покупателей с высоким уровнем дохода. Таких в этой стране немного и квартир гораздо меньше.

# %% [markdown]
# ##### Количество комнат (rooms)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['rooms'], bins=30, edgecolor='black')
plt.title('Распределение по количеству комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Выведем сводную таблицу по сегментам общей площади и количеству комнат
pivot_table_rooms = data.pivot_table(values='rooms', index='total_area_group', aggfunc=['mean', 'median', 'min', 'max', 'count'])
pivot_table_rooms
# Out:
#                           mean median   min   max  count
#                          rooms  rooms rooms rooms  rooms
# total_area_group
# дорогая недвижимость  3.980937    4.0     0    19   1836
# массовый сегмент      1.910214    2.0     0     6  21863

# %%
# Выведем сводную таблицу по сегментам цены и количеству комнат
pivot_table_rooms = data.pivot_table(values='rooms', index='last_price_group', aggfunc=['mean', 'median', 'min', 'max', 'count'])
pivot_table_rooms
# Out:
#                       mean median   min   max  count
#                      rooms  rooms rooms rooms  rooms
# last_price_group
# до 10 млн         1.900462    2.0     0     7  20977
# от 10 до 100 млн  3.356797    3.0     0    19   2685
# свыше 100 млн     5.216216    5.0     2    12     37

# %% [markdown]
# В сегменте дорогой недвижимости по размеру общей площади медианное количество комнат примерно в 2 раза больше, чем в массовом сегменте.
# Данные подтверждаются, если взглянуть на сводную таблицу по группам цен: квартиры до 10 млн относятся к массовому сегменту и имеют обычно 2 комнаты, квартиры дороже - от трёх комнат и более.

# %% [markdown]
# ##### Высота потолков

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['ceiling_height'], bins=30, edgecolor='black', range=(2, 5))
plt.title('Распределение по высоте потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Выведем количество квартир с высотой потолков > 4 метров или меньше 2,4 метров
data.query('ceiling_height > 4 or ceiling_height < 2.4')['ceiling_height'].count()
# Out:
# np.int64(76)

# %% [markdown]
# Допустим, что есть двухэтажные квартиры с высотой потолков 6 и 8 метров. Всё что больше - выглядит как выброс.
# К тому же, случаев экстремально высоких и экстремально низких потолков всего 48, поэтому их можно отбросить для построения гистограммы.

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['ceiling_height'], bins=30, edgecolor='black', range=(2.4, 4))
plt.title('Распределение по высоте потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# На графике видно, что типичная высота потолков - 2.7 метров, реже встречаются 2.5 метров и ещё реже - 3 м.
# Если не брать в расчёт 3-метровые потолки, высота свыше 2.8 метров почти не встречается в данных.

# %% [markdown]
# ##### Тип этажа квартиры («первый», «последний», «другой»)

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['floor_type'], bins=30, edgecolor='black')
plt.title('Распределение по типу этажа квартиры')
plt.xlabel('Тип этажа квартиры')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Также построим сводную таблицу для удобства
pivot_floor_type = data.pivot_table(index='floor_type', values='floor', aggfunc='count')
pivot_floor_type
# Out:
#             floor
# floor_type
# другой      17401
# первый       2917
# последний    3381

# %% [markdown]
# Количество квартир на первом и последнем этажах примерно равно. Преобладают квартиры в других этажах.
# Дополнительно оценим, как распределяется цена квартиры по этажам.

# %%
# Сформируем сводную таблицу по типам этажей и группам стоимости квартир
pivot_floor_type_by_price_group = data.pivot_table(index='floor_type', columns='last_price_group', values='floor', aggfunc='count')
pivot_floor_type_by_price_group
# Out:
# last_price_group  до 10 млн  от 10 до 100 млн  свыше 100 млн
# floor_type
# другой                15268              2111             22
# первый                 2771               145              1
# последний              2938               429             14

# %% [markdown]
# По всем ценовым сегментам прослеживается явная очевидная закономерность: больше квартир в средних этажах и меньше в первых и последних.
# В квартирах от 10 до 100 млн заметно, что предложений на последнем этаже побольше, с другой стороны - данных довольно мало и по ним нельзя делать выводы.

# %% [markdown]
# ##### Общее количество этажей в доме (floors_total)

# %% [markdown]
# Подробный анализ категории мы уже провели в п. **2.1.2 Этажей в доме (floors_total)**

# %% [markdown]
# ##### Расстояние до центра города в метрах (cityCenters_nearest)

# %%
# Для графика нам не нужны пропуски
ceiling_heights = data['cityCenters_nearest'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(ceiling_heights, bins=30, edgecolor='black')
plt.title('Распределение по расстоянию до центра города м')
plt.xlabel('Расстояние до центра города, м')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Создадим функцию и сгруппируем квартиры по следующим расстояниям до центра:
def group_cityCenters_nearest(cityCenters_nearest):
    
    # Если расстояние меньше 25 км
    if cityCenters_nearest <= 25000:
        return "до 25 км"
    
    # Если расстояние больше 25 км и меньше 50 км
    if cityCenters_nearest > 25000 and cityCenters_nearest <= 50000:
        return "от 25 до 50 км"

    # Иначе, свыше 50 км
    return "свыше 50 км"

# Применяем функцию классификации
data['cityCenters_nearest_group'] = data['cityCenters_nearest'].apply(group_cityCenters_nearest)

# %%
# Сформируем сводную таблицу по группам расстояний до центра
pivot_cityCenters_nearest_group = data.pivot_table(index='cityCenters_nearest_group', values='cityCenters_nearest', aggfunc='count')
pivot_cityCenters_nearest_group
# Out:
#                            cityCenters_nearest
# cityCenters_nearest_group
# до 25 км                                 16248
# от 25 до 50 км                            1746
# свыше 50 км                                186

# %%
# Сформируем сводную таблицу по группам расстояний до центра и группам населённых пунктов
pivot_cityCenters_nearest_by_locality_group = data.pivot_table(index='cityCenters_nearest_group', columns='locality_group', values='cityCenters_nearest', aggfunc='count')
pivot_cityCenters_nearest_by_locality_group
# Out:
# /tmp/ipykernel_6533/584900329.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_cityCenters_nearest_by_locality_group = data.pivot_table(index='cityCenters_nearest_group', columns='locality_group', values='cityCenters_nearest', aggfunc='count')
# locality_group             Окрестности  Санкт-Петербург
# cityCenters_nearest_group
# до 25 км                           681            15567
# от 25 до 50 км                    1653               93
# свыше 50 км                        186                0

# %% [markdown]
# Санкт-Петербург явно лидирует по инфраструктуре - добраться до центра города можно быстрее, так как почти во всех случаях расстояние меньше 25 км.
#
# Окрестностям повезло меньше - значительная часть квартир входит в диапазон 25 - 50 км.

# %% [markdown]
# ##### Расстояние до ближайшего парка (parks_nearest)

# %%
# Для графика нам не нужны пропуски
parks_nearest = data['parks_nearest'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(ceiling_heights, bins=30, edgecolor='black')
plt.title('Распределение по расстоянию до ближайшего парка м')
plt.xlabel('Расстояние до ближайшего парка, м')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Выведем медианное значение расстояние до ближайшего парка
data['parks_nearest'].median()
# Out:
# np.float64(455.0)

# %%
# Создадим функцию и сгруппируем квартиры по следующим расстояниям до ближайшего парка:
def group_parks_nearest(parks_nearest):
    
    # Если расстояние меньше 1 км
    if parks_nearest <= 1000:
        return "до 1 км"

    # Иначе, свыше 1 км
    return "свыше 1 км"

# Применяем функцию классификации
data['parks_nearest_group'] = data['parks_nearest'].apply(group_parks_nearest)

# %%
# Сформируем сводную таблицу по группам расстояний до ближайшего парка и группам населённых пунктов
pivot_parks_nearest_by_locality_group = data.pivot_table(index='parks_nearest_group', columns='locality_group', values='parks_nearest', aggfunc='count')
pivot_parks_nearest_by_locality_group
# Out:
# /tmp/ipykernel_6533/591484184.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_parks_nearest_by_locality_group = data.pivot_table(index='parks_nearest_group', columns='locality_group', values='parks_nearest', aggfunc='count')
# locality_group       Окрестности  Санкт-Петербург
# parks_nearest_group
# до 1 км                      766             6936
# свыше 1 км                    29              348

# %% [markdown]
# Вне зависимости от типа населённого пункта доля квартир, находящихся на расстоянии более 1 км от парка колеблется в районе 3-5%.
#
# Критических значений и выбросов не выявлено.

# %% [markdown]
#  <div class="alert alert-success">
# ✔️ Комментарий ревьюера v2✔️
#
# Хороший результат. Хочу добавить, что обычно размеры двухкомнатных квартир составляют от 50 до 100 квадратных метров, что и соответствует проведенному анализу.
#
# Молодец, что стараешься оформлять графики.
#
# `Обращаю внимание, что графики с заголовками и подписями осей выглядят в отчетах более выигрышно и ценятся руководством`
#
# Могу посоветовать также хорошую статью по оформлению графиков:
#     https://devpractice.ru/matplotlib-lesson-3-3-text-elements/
# </div>

# %% [markdown]
# #### Исследуем скорость продажи квартир (days_exposition)

# %%
# Построим гистограмму
plt.figure(figsize=(8, 6))
plt.hist(data['days_exposition'], bins=30, edgecolor='black')
plt.title('Распределение по дням размещения объявления')
plt.xlabel('Дни размещения объявления')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# Посчитаем среднее и медиану
days_exposition_mean = data['days_exposition'].mean().round(2)
days_exposition_median = data['days_exposition'].median()

print(f'Среднее: {days_exposition_mean}, медиана: {days_exposition_median}')
# Out:
# Среднее: 180.89, медиана: 95.0

# %% [markdown]
# **Интерпретируем данные:**
# - Обычно продажа занимает около 95 дней (медиана), то есть половина квартир продаётся за это время или быстрее. Это отражает типичное время продажи.
# - Продажи быстрее 95 дней можно считать быстрыми, так как это быстрее, чем медиана. Например, если квартира продаётся в течение месяца (30-60 дней), это будет быстрая продажа.
# - Продажи дольше 180.89 дней (среднее) можно считать необычно долгими. Значит, если квартира продаётся более 6 месяцев (например, 200–300 дней), это может указывать на определённые проблемы с продажей (неподходящая цена, низкий спрос и т.д.).
#
# **Быстрая продажа:**
#
# - Продажа, которая занимает меньше 95 дней, считается быстрой.
#
# **Необычно долгая продажа:**
#
# Продажа, которая занимает дольше 180.89 дней, считается необычно долгой, так как среднее значение выше медианы из-за влияния выбросов — долгих продаж.
#
# Таким образом, типичное время продажи — это около 95 дней, а всё, что сильно выходит за эти пределы (особенно более 6 месяцев), можно считать необычным.

# %%
# Код ревьюера
data['days_exposition'].hist(bins=50, range=(0,100), figsize=(12, 7))
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера v2❌**
#
#    На гистограмме действительно заметны пики примерно через 45, 60 и 90 дней после начала продажи. Можно посмотреть на условия размещения объявлений в Яндекс.Недвижимости - https://yandex.ru/support/realty/owner/home/add-ads-housing.html С учетом того, что после формирования датасета правила размещения поменялись, эти пики являются следами автоматического снятия объявлений - поэтому оценивать скорость продажи стоит по диаграмме размаха, взяв за быстрые продажи до 1 квартиля, за долгие после третьего
#
#
#
#
# </div>

# %%
# Рассчитаем первый и третий квартили
q1 = data['days_exposition'].quantile(0.25)
q3 = data['days_exposition'].quantile(0.75)

# Построим диаграмму размаха с ограничением по оси X в диапазоне от 0 до 100 дней
plt.figure(figsize=(10, 6))
plt.boxplot(data['days_exposition'].dropna(), vert=False)
plt.title('Диаграмма размаха (Boxplot) времени продажи квартир (0-100 дней)')
plt.xlabel('Количество дней на продажу')

# Отметим квартили на графике
plt.axvline(q1, color='green', linestyle='--', label=f'Q1: {q1:.2f} дней')
plt.axvline(q3, color='red', linestyle='--', label=f'Q3: {q3:.2f} дней')

# Выведем результаты
print(f'Первый квартиль (Q1): {q1:.0f} дней')
print(f'Третий квартиль (Q3): {q3:.0f} дня')

# Интерпретируем данные:
# Быстрая продажа — до Q1 дней
# Обычная продажа — от Q1 до Q3 дней
# Долгая продажа — после Q3 дней
# Out:
# Первый квартиль (Q1): 45 дней
# Третий квартиль (Q3): 232 дня

# %% [markdown]
# Первый квартиль (Q1) показывает порог для быстрых продаж, а третий квартиль (Q3) — для долгих продаж. Продажи между Q1 и Q3 считаются обычными.
#
# **Интерпретация:**
#
# - Быстрая продажа: Продажа, которая занимает меньше, чем первый квартиль (Q1) дней.
# - Обычная продажа: Продажа, которая занимает от первого до третьего квартиля (Q1-Q3) дней.
# - Долгая продажа: Продажа, которая занимает больше, чем третий квартиль (Q3) дней.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Дополнил анализ.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Теперь верно👍
#
# </div>
#
# </div>

# %% [markdown]
# #### Определяем факторы, влияющие на стоимость объекта

# %% [markdown]
# ##### Зависимость цены от общей площади

# %%
# Подготовим сводную таблицу зависимости цены от общей площади
pivot_price_total_area = data.pivot_table(values='last_price', index='total_area', aggfunc='mean').reset_index()
pivot_price_total_area
# Out:
#       total_area   last_price
# 0           12.0    2400000.0
# 1           13.0    2350000.0
# 2           13.2    1686000.0
# 3           14.0    1190000.0
# 4           15.0    1725000.0
# ...          ...          ...
# 2177       590.0   65000000.0
# 2178       618.0  300000000.0
# 2179       631.0  140000000.0
# 2180       631.2  140000000.0
# 2181       900.0  420000000.0
#
# [2182 rows x 2 columns]

# %%
# Построим график зависимости цены от общей площади
plt.figure(figsize=(10, 6))
plt.scatter(pivot_price_total_area['total_area'], pivot_price_total_area['last_price'], alpha=0.5, c='blue', edgecolors='black')
plt.title('Зависимость цены от общей площади')
plt.xlabel('Общая площадь (кв.м)')
plt.ylabel('Стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Даже не смотря на выбросы, заметна зависимость стоимости цены от общей площади квартиры. Чем площадь больше, тем дороже квартира.
# Интересно, что в некоторых случаях квартиры с одинаковой площадью могут сильно различаться в цене. Разброс увеличивается при увеличении площади.

# %% [markdown]
# ##### Зависимость цены от жилой площади

# %%
# Подготовим сводную таблицу зависимости цены от жилой площади
pivot_price_living_area = data.pivot_table(values='last_price', index='living_area', aggfunc='mean').reset_index()
pivot_price_living_area
# Out:
#       living_area   last_price
# 0        2.000000    4340000.0
# 1        3.000000   34715000.0
# 2        5.000000    2680000.0
# 3        5.400000    6100000.0
# 4        6.000000    3799000.0
# ...           ...          ...
# 2627   334.409592  230000000.0
# 2628   347.500000   91500000.0
# 2629   404.708737  140000000.0
# 2630   409.000000   65000000.0
# 2631   409.700000  420000000.0
#
# [2632 rows x 2 columns]

# %%
# Построим график зависимости цены от жилой площади
plt.figure(figsize=(10, 6))
plt.scatter(pivot_price_living_area['living_area'], pivot_price_living_area['last_price'], alpha=0.5, c='blue', edgecolors='black')
plt.title('Зависимость цены от жилой площади')
plt.xlabel('Жилая площадь (кв.м)')
plt.ylabel('Стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Стоимость квартиры также зависит и от жилой площади. Чем больше жилая площадь, тем дороже квартира. Разброс цен также растёт с увеличением жилой площади.

# %% [markdown]
# ##### Зависимость цены от площади кухни

# %%
# Подготовим сводную таблицу зависимости цены от площади кухни
pivot_price_kitchen_area = data.pivot_table(values='last_price', index='kitchen_area', aggfunc='mean').reset_index()
pivot_price_kitchen_area
# Out:
#       kitchen_area    last_price
# 0         1.300000  4.250000e+06
# 1         2.000000  2.821429e+06
# 2         2.053430  2.450000e+06
# 3         2.119670  2.100000e+06
# 4         2.252149  1.500000e+06
# ...            ...           ...
# 1944    100.000000  6.500000e+07
# 1945    100.700000  1.250000e+07
# 1946    107.000000  8.500000e+07
# 1947    112.000000  4.200000e+08
# 1948    123.478328  4.318533e+07
#
# [1949 rows x 2 columns]

# %%
# Построим график зависимости цены от площади кухни
plt.figure(figsize=(10, 6))
plt.scatter(pivot_price_kitchen_area['kitchen_area'], pivot_price_kitchen_area['last_price'], alpha=0.5, c='blue', edgecolors='black')
plt.title('Зависимость цены от площади кухни')
plt.xlabel('Площадь кухни (кв.м)')
plt.ylabel('Стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Ситуация повторилась и для площади кухни. Чем она больше, тем дороже квартира.
#
# Общий вывод по зависимости цены квартиры от площади: чем площадь больше, тем дороже будет квартира. Чем больше площадь, тем выше разброс цен.
# Квартиры массового сегмента (общая площадь менее 100 квм) имеют большую стабильность в цене. Для дорогих квартир (более 100 квм) вариативность цены выше.

# %% [markdown]
# ##### Зависимость цены от количества комнат

# %%
# Подготовим сводную таблицу зависимости цены от количества комнат
pivot_price_rooms = data.pivot_table(values='last_price', index='rooms', aggfunc='mean').reset_index()
pivot_price_rooms
# Out:
#     rooms    last_price
# 0       0  3.337724e+06
# 1       1  3.835362e+06
# 2       2  5.593139e+06
# 3       3  8.179119e+06
# 4       4  1.342350e+07
# 5       5  2.376208e+07
# 6       6  3.170975e+07
# 7       7  5.147007e+07
# 8       8  5.022417e+07
# 9       9  3.415236e+07
# 10     10  2.616667e+07
# 11     11  2.525000e+07
# 12     12  4.200000e+08
# 13     14  2.682950e+07
# 14     15  6.500000e+07
# 15     16  2.850000e+07
# 16     19  3.225000e+07

# %%
# Построим график зависимости цены от количества комнат
plt.figure(figsize=(10, 6))
plt.scatter(pivot_price_rooms['rooms'], pivot_price_rooms['last_price'], alpha=0.5, c='blue', edgecolors='black')
plt.title('Зависимость цены от количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# А вот количество комнат является значительным фактором, влияющим на цену только до 5. Дальше медианная цена колеблется в пределах 1 млн рублей. Имеется 1 выброс: 12-комнатная квартира стоит больше 4 млн рублей.
#
# Выходит, что между медианной квартирой с 6 комнатами и квартирой с 19 комнатами совсем незначительная разница.

# %% [markdown]
# ##### Зависимость цены от типа этажа

# %%
# Подготовим сводную таблицу зависимости средней цены от типа этажа
pivot_price_floor_type_mean = data.pivot_table(values='last_price', index='floor_type', aggfunc='mean').reset_index()
pivot_price_floor_type_mean
# Out:
#   floor_type    last_price
# 0     другой  6.677511e+06
# 1     первый  4.803560e+06
# 2  последний  7.344864e+06

# %%
plt.figure(figsize=(10, 6))
plt.bar(pivot_price_floor_type_mean['floor_type'], pivot_price_floor_type_mean['last_price'], color=['blue', 'green', 'red'])
plt.title('Зависимость цены от типа этажа')
plt.xlabel('Тип этажа')
plt.ylabel('Средняя стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Самую низкую цену предлагают обычно за квартиры на первых этажах, видимо это связано с безопасностью.
# Самую высокую - на последних этажах.
# На других этажах обычно цены ближе к ценам на последних этажа.
#
# Это странно, потому что я ожидал, что цены на других этажах будут выше, ведь последние этажи обычно сильно нагреваются летом из-за крыши, а зимой подвержены протечкам с той же крыши.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#    В таком случае стоит взять не по средним (mean), а по медиане (median) - она не будет подвержена выбросам, связанными с высокой стоимостью элитного жилья на последних этажах - и тогда как раз наибольшая стоимость окажется у квартир, расположенных не на первых и не на последних этажах
#
# </div>

# %%
# Подготовим сводную таблицу зависимости медианной цены от типа этажа
pivot_price_floor_type_median = data.pivot_table(values='last_price', index='floor_type', aggfunc='median').reset_index()
pivot_price_floor_type_median
# Out:
#   floor_type  last_price
# 0     другой   4850000.0
# 1     первый   3900000.0
# 2  последний   4330000.0

# %%
plt.figure(figsize=(10, 6))
plt.bar(pivot_price_floor_type_median['floor_type'], pivot_price_floor_type_median['last_price'], color=['blue', 'green', 'red'])
plt.title('Зависимость цены от типа этажа')
plt.xlabel('Тип этажа')
plt.ylabel('Медианная стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Да, действительно, сравнение по медианной цене отличается от аналогичного по средней и удовлетсоряет ожиданиям - самые дорогие квартиры находятся на промежуточных этажах.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Хорошие результаты. Отмечу, что скорее всего, низкую цену на квартиры на первом и последнем этажах можно аргументировать плохими условиями - шум от улиц и моторов лифта, охлаждаемость помещения зимой.
#
# </div>
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   total_images               23699 non-null  int64
#  1   last_price                 23699 non-null  float64
#  2   total_area                 23699 non-null  float64
#  3   first_day_exposition       23699 non-null  datetime64[ns]
#  4   rooms                      23699 non-null  int64
#  5   ceiling_height             23699 non-null  float64
#  6   floors_total               23699 non-null  int64
#  7   living_area                23699 non-null  float64
#  8   floor                      23699 non-null  float64
#  9   is_apartment               23699 non-null  bool
#  10  studio                     23699 non-null  bool
#  11  open_plan                  23699 non-null  bool
#  12  kitchen_area               23699 non-null  float64
# ...

# %% [markdown]
# ##### Зависимость цены от даты размещения (день недели, месяц, год)

# %%
# Подготовим сводную таблицу зависимости цены от дня недели размещения
pivot_price_weekday = data.pivot_table(values='last_price', index='weekday_of_exposition', aggfunc='mean').reset_index()
pivot_price_weekday
# Out:
#    weekday_of_exposition    last_price
# 0                      0  6.511613e+06
# 1                      1  6.394233e+06
# 2                      2  6.631035e+06
# 3                      3  6.708663e+06
# 4                      4  6.372131e+06
# 5                      5  6.976804e+06
# 6                      6  6.246180e+06

# %%
plt.figure(figsize=(10, 6))
plt.bar(pivot_price_weekday['weekday_of_exposition'], pivot_price_weekday['last_price'])
plt.title('Зависимость цены от дня недели размещения')
plt.xlabel('День недели размещения')
plt.ylabel('Средняя стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Чуть-чуть дороже медианные цены в пятницу. Различия несущественны.
# Похоже, что не зависит цена от дня недели размещения.

# %%
# Подготовим сводную таблицу зависимости цены от месяца
pivot_price_month = data.pivot_table(values='last_price', index='month_of_exposition', aggfunc='mean').reset_index()
pivot_price_month
# Out:
#     month_of_exposition    last_price
# 0                     1  6.668233e+06
# 1                     2  6.468500e+06
# 2                     3  6.363983e+06
# 3                     4  6.737198e+06
# 4                     5  6.600435e+06
# 5                     6  6.310269e+06
# 6                     7  6.649337e+06
# 7                     8  6.350233e+06
# 8                     9  6.825470e+06
# 9                    10  6.235013e+06
# 10                   11  6.461363e+06
# 11                   12  7.011731e+06

# %%
plt.figure(figsize=(12, 6))
plt.bar(pivot_price_month['month_of_exposition'], pivot_price_month['last_price'])
plt.title('Зависимость цены от месяца размещения')
plt.xlabel('Месяц размещения')
plt.ylabel('Средняя стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# Декабрь является самым "дорогим" месяцем для размещения квартир. Различие также несущественно, медианная цена колеблется в диапазоне от 6 до 7 млн в каждый месяц.

# %%
# Подготовим сводную таблицу зависимости цены от года
pivot_price_year = data.pivot_table(values='last_price', index='year_of_exposition', aggfunc='mean').reset_index()
pivot_price_year
# Out:
#    year_of_exposition    last_price
# 0                2014  1.208714e+07
# 1                2015  8.572833e+06
# 2                2016  6.827912e+06
# 3                2017  6.585729e+06
# 4                2018  5.950966e+06
# 5                2019  6.786618e+06

# %%
plt.figure(figsize=(12, 6))
plt.bar(pivot_price_year['year_of_exposition'], pivot_price_year['last_price'])
plt.title('Зависимость цены от года размещения')
plt.xlabel('Год размещения')
plt.ylabel('Средняя стоимость квартиры (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# А вот от года зависимость на первый взгляд присутствует: в 2014 году цена медианной квартиры была существенно выше, при этом количество таких квартир всего 137, что говорит о недостаточной выборке, по которой нельзя делать выводы.
#
# В 2015 году было выставлено на продажу квартир по медианной цене, которая выше таковой в последующих годах и количество таких квартир - 1191. Выборка существенная, вывод можно сделать - в 2015 году квартиры были дороже всего.
#
# В 2018 году квартиры были наиболее дешёвыми.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#   Стоит также посмотреть на динамику изменения площади продаваемых квартир по годам. Возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера v2❌**
#
#    От площадей стоимость зависит линейно, поэтому мы можем посмотреть также на силу зависимости, используя коэффициент корреляции Пирсона - построй, пожалуйста, матрицу корреляций для столбцов, от которых стоимость зависит линейно - вот полезная ссылка: https://www.codecamp.ru/blog/correlation-matrix-in-python/
#
# </div>

# %%
# Построим сводную таблицу для изменения средней площади квартир по годам
pivot_area_year = data.pivot_table(values='total_area', index='year_of_exposition', aggfunc='mean').reset_index()
pivot_area_year
# Out:
#    year_of_exposition  total_area
# 0                2014   86.249854
# 1                2015   71.558371
# 2                2016   62.156144
# 3                2017   60.759249
# 4                2018   57.677386
# 5                2019   59.467864

# %%
# Построим графика изменения площади квартир по годам
plt.figure(figsize=(12, 6))
plt.bar(pivot_area_year['year_of_exposition'], pivot_area_year['total_area'])
plt.title('Изменение площади продаваемых квартир по годам')
plt.xlabel('Год размещения')
plt.ylabel('Средняя площадь квартиры (кв.м)')
plt.grid(True)
plt.show()

# %%
# Построим матрицу корреляций для столбцов, влияющих на стоимость
# Для корреляции Пирсона подойдут числовые параметры: общая площадь, жилая площадь, кухня и цена
correlation_matrix = data[['last_price', 'total_area', 'living_area', 'kitchen_area']].corr()
correlation_matrix
# Out:
#               last_price  total_area  living_area  kitchen_area
# last_price      1.000000    0.653741     0.586270      0.496800
# total_area      0.653741    1.000000     0.946826      0.637364
# living_area     0.586270    0.946826     1.000000      0.475801
# kitchen_area    0.496800    0.637364     0.475801      1.000000

# %%
# Выбираем нужные столбцы для анализа корреляции
columns_for_analysis = ['last_price', 'total_area', 'living_area', 'kitchen_area']

# Построение матрицы диаграмм рассеяния
pd.plotting.scatter_matrix(data[columns_for_analysis], figsize=(10, 10))

plt.suptitle('Матрица диаграмм рассеяния для параметров стоимости квартиры')
plt.show()

# %% [markdown]
# **Корреляция цены с площадью:**
# - Общая площадь квартиры оказалась основным фактором, влияющим на стоимость: коэффициент корреляции между ценой и общей площадью составил 0.65, что указывает на сильную положительную зависимость.
# - Жилая площадь также оказала влияние на цену, но её корреляция немного ниже — 0.59.
# - Площадь кухни имеет умеренную корреляцию с ценой (0.50), что подтверждает, что она оказывает влияние, но не является основным фактором при определении стоимости квартиры.

# %% [markdown]
# **Общий вывод:**
# - **Цена зависит от площади:**
#
# Анализ корреляций показывает, что площадь квартиры, особенно общая площадь, значительно влияет на стоимость. Чем больше площадь, тем дороже объект недвижимости. Это объясняет часть динамики изменения цен: снижение средней площади продаваемых квартир приводит к снижению средней цены.
#
# - **Изменение площади квартир по годам:**
#
# Данные указывают на тенденцию к продаже квартир меньшей площади в последние годы (особенно после 2016 года). Это привело к снижению средней стоимости квартир, но не потому, что цены на квадратный метр упали, а из-за изменения структуры предложения.
#
# - **Оценка по годам:**
#
# В 2014 и 2015 годах наблюдались высокие цены, вероятно, связанные с продажей квартир большей площади.
# В 2018 году квартиры были наиболее дешёвыми, что может быть связано с их меньшей площадью.
#
# - **Корреляция подтверждает:**
#
# Коэффициенты корреляции подтверждают, что стоимость квартиры в первую очередь определяется общей площадью. Это значит, что снижение цен после 2015 года в значительной степени связано с уменьшением продаваемых квартир по площади.
#
# Динамика изменения средней стоимости может быть ложной, если не учитывать изменение площади продаваемых объектов.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Дополнил анализ.
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Также можно предположить, что стали чаще совершаться сделки с квартирами меньшей площади, ввиду их более высокой ликвидности
#
# </div>
#
# </div>

# %% [markdown]
# #### Анализ 10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.

# %%
# Создаем сводную таблицу с количеством объявлений и средней ценой за квадратный метр
pivot_table = data.pivot_table(values='price_per_sqm', index='locality_name', aggfunc=['mean', 'count']).reset_index()

# Переименовываем колонки для удобства
pivot_table.columns = ['locality_name', 'avg_price_per_sqm', 'ad_count']

# Сортируем по количеству объявлений и выбираем топ-10 населенных пунктов
top_10_localities = pivot_table.sort_values(by='ad_count', ascending=False).head(10)

# Находим населённые пункты с самой высокой и самой низкой средней ценой за квадратный метр
max_price_locality = top_10_localities.loc[top_10_localities['avg_price_per_sqm'].idxmax()]
min_price_locality = top_10_localities.loc[top_10_localities['avg_price_per_sqm'].idxmin()]

# Вывод результатов
print("Топ-10 населённых пунктов по количеству объявлений:")
print(top_10_localities)

print(f"\nНаселённый пункт с самой высокой средней ценой за квадратный метр: {max_price_locality['locality_name']}, {max_price_locality['avg_price_per_sqm']:.0f} руб.")
print(f"Населённый пункт с самой низкой средней ценой за квадратный метр: {min_price_locality['locality_name']}, {min_price_locality['avg_price_per_sqm']:.0f} руб.")
# Out:
# Топ-10 населённых пунктов по количеству объявлений:
#          locality_name  avg_price_per_sqm  ad_count
# 33     Санкт-Петербург      114849.008793     15721
# 216     поселок Мурино       85681.762572       556
# 276     поселок Шушары       78677.364318       440
# 3           Всеволожск       68654.473970       398
# 32              Пушкин      103125.819377       369
# 13             Колпино       75424.579112       338
# 223  поселок Парголово       90175.913089       327
# 6              Гатчина       68746.146515       307
# 92     деревня Кудрово       92473.547559       299
# 4               Выборг       58141.909325       237
#
# Населённый пункт с самой высокой средней ценой за квадратный метр: Санкт-Петербург, 114849 руб.
# Населённый пункт с самой низкой средней ценой за квадратный метр: Выборг, 58142 руб.
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Верно
#
# </div>

# %% [markdown]
# #### Вычисление средней стоимости квартир в Санкт-Петербурге на разном удалении от центра

# %%
# Выделяем квартиры в Санкт-Петербурге
spb_flats = data[data['locality_name'] == 'Санкт-Петербург']

# Преобразуем расстояние до центра в километры и округляем до целого километра
spb_flats['cityCenters_nearest_km'] = (spb_flats['cityCenters_nearest'] / 1000).round()

# Создаем сводную таблицу для вычисления средней стоимости квартир на разном удалении от центра
pivot_spb = spb_flats.pivot_table(values='last_price', index='cityCenters_nearest_km', aggfunc='mean').reset_index()

# Построим график изменения средней цены для каждого километра
plt.figure(figsize=(10, 6))
plt.plot(pivot_spb['cityCenters_nearest_km'], pivot_spb['last_price'], marker='o', linestyle='-', color='b')
plt.title('Изменение средней цены квартир по расстоянию от центра Санкт-Петербурга')
plt.xlabel('Расстояние до центра (км)')
plt.ylabel('Средняя цена квартиры (руб.)')
plt.grid(True)
plt.show()

# Вывод сводной таблицы
print(pivot_spb)
# Out:
# /tmp/ipykernel_6533/403258489.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spb_flats['cityCenters_nearest_km'] = (spb_flats['cityCenters_nearest'] / 1000).round()
#     cityCenters_nearest_km    last_price
# 0                      0.0  3.144912e+07
# 1                      1.0  2.120672e+07
# 2                      2.0  1.778832e+07
# 3                      3.0  1.112658e+07
# 4                      4.0  1.330428e+07
# 5                      5.0  1.449912e+07
# 6                      6.0  1.533842e+07
# 7                      7.0  1.477515e+07
# 8                      8.0  9.957717e+06
# 9                      9.0  6.971195e+06
# 10                    10.0  6.504119e+06
# 11                    11.0  6.250815e+06
# ...

# %% [markdown]
# На основе представленных данных можно сделать следующие выводы о зависимости стоимости объектов недвижимости от расстояния до центра Санкт-Петербурга:
#
# 1. **Цены резко снижаются по мере увеличения расстояния от центра**:
#
#    - Вблизи центра (0-3 км) цены на квартиры значительно выше. Например, на расстоянии 0 км средняя цена составляет около 31,4 миллиона рублей, на 1 км — около 21,2 миллиона, а на 3 км — около 11,1 миллиона рублей.
#    - Это связано с высокой престижностью центральных районов, где сосредоточены деловые и культурные центры.
#
#
# 2. **От 4 до 7 км — колебания, затем постепенное снижение**:
#
#    - На расстоянии 4-7 км цены колеблются в диапазоне 13-15 миллионов рублей, что может быть связано с наличием престижных районов за пределами центра.
#    - После этого происходит постепенное снижение цен до 10 км, где средняя стоимость уже составляет около 6,5 миллионов рублей.
#
#
# 3. **Стабилизация после 10 км**:
#
#    - Начиная с 10 км от центра, средняя стоимость объектов постепенно снижается, но колеблется в диапазоне 5-6 миллионов рублей на расстоянии от 10 до 22 км.
#    - Это может свидетельствовать о том, что на большом удалении от центра объекты становятся более однородными с точки зрения стоимости.
#
#
# 4. **Резкое снижение после 23 км**:
#
#    - Начиная с 23 км, цены падают до 3,8 миллионов рублей на 24 км и остаются ниже 5 миллионов рублей на более удалённых участках. Это типично для пригородных или менее престижных районов.
#
#
# 5. **Аномальные значения**:
#
#    - На расстоянии 27 км наблюдается всплеск цены до 8,3 миллионов рублей, что может указывать на присутствие элитных объектов или районов с престижной загородной недвижимостью.
#    - Такие выбросы могут быть связаны с отдельными элитными объектами за пределами города.
#
# - **Центральные районы (0-3 км)** характеризуются самой высокой стоимостью недвижимости, которая значительно выше среднего по городу.
# - По мере удаления от центра цены плавно снижаются, особенно после 7 км, но стабилизируются на расстоянии около 10-22 км.
# - На расстоянии более 23 км начинается дальнейшее снижение цен, что характерно для пригородных и менее престижных районов.

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера v2✔️
#
# Верно. На графике после 7 км заметно, что цена меняется. Это возможный центр города.
#
# Если интересно, то самый дорогой по стоимости жилья район в Санкт-Петербурге риелторы назвали "Золотой треугольник". Дома "Золотого треугольника" находятся в пределах Невского проспекта, набережной реки Фонтанки и Дворцовой набережной.
# Для географической справки: https://zen.yandex.ru/media/id/5cb4ebcc0a51a300b5b1f60d/zolotoi-treugolnik-sanktpeterburga-chto-eto-i-gde-nahoditsia-5edf942db1204610073e88b2
#
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# Исходя из представленного исследования, можно сделать следующие итоговые выводы:
#
# 1. **Распределение высоты потолков**
#
# Большинство квартир имеют высоту потолков в диапазоне от 2,5 до 3 метров. Пропуски в данных по высоте потолков могут возникать из-за отсутствия обязательности указания этого параметра, его неважности для продавцов, или затруднений в точных измерениях. Для заполнения пропусков лучше использовать медианные значения, так как они меньше подвержены влиянию выбросов.
#
# 2. **Количество этажей**
#
# Часто встречающиеся значения этажей в домах — это 5, 9, 16 и 25 этажей. Пропуски в данных по этажности можно заполнить, сгруппировав населённые пункты по категориям (Санкт-Петербург, Окрестности) и используя медианные значения в каждой категории.
#
# 3. **Жилая и кухонная площади**
#
# В распределении жилой площади наблюдается зависимость от общей площади и количества комнат, а для кухни зависимость схожа — с увеличением количества комнат площадь кухни становится меньше по сравнению с общей площадью. Пропуски в этих данных могут быть вызваны отсутствием обязательных указаний, трудностями в замерах, или перепланировками. Пропуски можно заполнить медианными значениями для каждой группы по количеству комнат.
#
# 4. **Пропуски названий населённых пунктов**
#
# Они могут быть вызваны ошибками ввода данных или отсутствием информации о недавно застроенных или малоизвестных населённых пунктах. Пропуски можно заменить на "Неизвестный".
#
# 5. **Удалённость объектов от аэропортов и других инфраструктурных объектов**
#
# Пропуски в этих данных могут быть связаны с отсутствием инфраструктуры рядом с объектом недвижимости или с техническими ошибками при сборе данных. Заполнять их средними или медианными значениями нецелесообразно.
#
# 6. **Апартаменты**
#
# Данные о том, является ли объект апартаментом, содержат только значения 0 и 1. Этот столбец можно преобразовать в булевый тип для экономии памяти и повышения удобства работы с данными.
#
# 7. **Цены на недвижимость**
#
# Цена квартиры сильно зависит от её общей, жилой площади и количества комнат. Чем больше площадь, тем выше цена, при этом разброс цен также увеличивается с ростом площади. В массовом сегменте (до 100 кв.м) цены более стабильны, в то время как в дорогом сегменте (свыше 100 кв.м) наблюдается большая вариативность цен.
#
# 8. **Зависимость цены от этажа**
#
# Самые низкие цены наблюдаются на первых этажах, в то время как последние этажи часто имеют более высокие цены, что может быть связано с престижностью верхних этажей или уникальными предложениями, такими как пентхаусы.
#
# 9. **День недели и месяц размещения объявления**
#
# Заметных изменений цены в зависимости от дня недели или месяца размещения объявления не наблюдается, за исключением того, что квартиры в декабре несколько дороже.
#
# 10. **Зависимость цены от года размещения**
#
# В 2015 году цены на квартиры были выше по сравнению с последующими годами. Возможно, это связано с экономической ситуацией в стране на тот момент. В 2018 году цены достигли самого низкого уровня.
#
# 11. **Населённые пункты с самой высокой и низкой стоимостью за квадратный метр**
#
# Самая высокая средняя стоимость за квадратный метр наблюдается в Санкт-Петербурге (114849 руб.), а самая низкая — в Выборге (58142 руб.).
#
# 12. **Зависимость цены от расстояния до центра Санкт-Петербурга**
#
# Чем ближе квартира к центру города, тем выше её стоимость. На расстоянии от 0 до 3 км цены могут достигать 31,4 млн рублей, после чего они плавно снижаются и стабилизируются на уровне 5-6 млн рублей на расстоянии 10-22 км. За пределами 23 км цены падают до 3,8 млн рублей.
#
# **Итоговый вывод**
#
# Значительная часть ценовых и инфраструктурных параметров недвижимости зависит от общих характеристик объекта (площадь, количество комнат, этажность), а также от его местоположения. Выявленные зависимости и корректировки в данных помогают сделать выводы о типичных параметрах объектов недвижимости и выявить закономерности, которые можно использовать для прогнозирования цен и анализа рынка.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Николай, проведен основательный и подробный анализ. Все наглядно - графики и гистограммы подтверждают обоснованные выводы. Учти мои замечания. Возможно, придется немного подправить выводы. Жду твой проект на повторное ревью. Успехов!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Николай, замечания устранены 👍. Уверен, мои советы пригодятся тебе в новых проектах. Успехов в обучении! 😉
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [х]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [х]  Найдены пропущенные значения.
# - [х]  Пропущенные значения заполнены там, где это возможно.
# - [х]  Объяснено, какие пропущенные значения обнаружены.
# - [х]  В каждом столбце установлен корректный тип данных.
# - [х]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [х]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [х]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [х]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [х]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [х]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [х]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [х]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [х]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [х]  На каждом этапе сделаны промежуточные выводы.
# - [х]  В конце проекта сделан общий вывод.
